# %% [markdown]
# # Data Collection Pipeline V4 - Pareto Top-N Approach
#
# ## Two-Phase Approach:
#
# ### Phase 1: Build Cost Pool
# - Generate random cost parameters
# - Optimize each with ODL API
# - Store (costs, features) pairs
# - Can skip if you already have cost_pool.json
#
# ### Phase 2: Match Preferences (New!)
# - Generate random preferences
# - Get **top 30 solutions** from pool (closest to ideal)
# - Use **Pareto evaluation** to select best
# - Save training samples
#
# ## Benefits:
# - ✅ 30 unique outputs (vs 5-7 with old method)
# - ✅ High quality (top 15% of solutions)
# - ✅ No arbitrary scaling factors
# - ✅ Ready for regression training

# %% [markdown]
# ## 1. Imports

# %%
import json
import time
import requests
import numpy as np
import pandas as pd
from datetime import datetime
from pathlib import Path
import copy
from typing import List, Dict
import os

print("✓ Imports successful")
# Out:
# ✓ Imports successful

# %% [markdown]
# ## 2. Configuration
#
# **⚠️ UPDATE THESE VALUES:**

# %%
# API Configuration


# Model file (use relaxed version without skill requirements)
MODEL_PATH = "../test_model_relaxed.json"  # ← CHANGE THIS

# Phase 1: Cost Pool Generation
POOL_SIZE = 200  # Number of cost sets to generate
WAIT_SECONDS = 60  # Wait time for optimization (can be 30-120s)
CHECKPOINT_EVERY = 10  # Save progress every N samples
POOL_FILE = "cost_pool.json"  # Output file

# Phase 2: Training Data Generation  
N_SAMPLES = 400  # Number of training samples to generate
TOP_N = 100  # Use top N solutions from pool (30 = good diversity)
TOP_K = 3  # Use top K solutions to form Pareto front (30 = good diversity)
# Output will be auto-created in timestamped folder: training_data_YYYYMMDD_HHMMSS/

# Cost parameter ranges
COST_RANGES = {
    'costPerTravelHour': (0.5, 5.0),
    'costPerKm': (0.01, 0.5),
    'parking_multiplier': (0.2, 2.0)
}


# Sampling Strategy
USE_DIVERSE_SAMPLING = True  # Use strategic sampling for diverse Pareto front



print(f"Configuration loaded:")
print(f"  Pool size: {POOL_SIZE}")
print(f"  Training samples: {N_SAMPLES}")
print(f"  Top-N selection: {TOP_N}")
print(f"  Estimated Phase 1 time: {(POOL_SIZE * WAIT_SECONDS) / 3600:.1f} hours")
# Out:
# Configuration loaded:
#   Pool size: 200
#   Training samples: 400
#   Top-N selection: 100
#   Estimated Phase 1 time: 3.3 hours

# %% [markdown]
# ## 🎯 Strategic Diverse Sampling (V6 Update)
#
# **New in V6:** The pipeline now uses **strategic diverse sampling** instead of pure random sampling.
#
# ### Why?
# - Pure random sampling → Small Pareto front (7-10 solutions)
# - Strategic sampling → Larger Pareto front (20-40 solutions)
# - Better training data diversity for regression
#
# ### How it works:
# The `sample_diverse_costs()` method randomly chooses one of 5 strategies:
#
# 1. **Time-focused** (20%): High time costs → Fast routes preferred
# 2. **Distance-focused** (20%): High distance costs → Short routes preferred
# 3. **Parking-focused** (20%): High parking costs → Easy parking preferred
# 4. **Balanced** (20%): Moderate costs → Balanced solutions
# 5. **Random** (20%): Wide ranges → Exploration
#
# This ensures your cost pool covers the entire feature space, not just one corner!
#
# ### Recommended pool sizes:
# - **Quick test**: 100 samples (~1 hour) → Expect 15-25 Pareto solutions
# - **Standard**: 200 samples (~2 hours) → Expect 25-40 Pareto solutions
# - **Comprehensive**: 300 samples (~3 hours) → Expect 35-50 Pareto solutions
#
# **Note:** With diverse sampling, 200-300 samples is usually sufficient. More samples won't significantly increase Pareto front size.

# %% [markdown]
# ## 3. Pareto Analyzer Class

# %%
class ParetoAnalyzer:
    """Top-N + Pareto selection for cost pool matching"""
    
    def __init__(self, cost_pool: List[Dict]):
        self.cost_pool = cost_pool
        self.objectives = ['avg_parking_difficulty', 'total_travel_hours', 'total_distance_km']
    
    def get_top_n_solutions(self, n=30) -> List[Dict]:
        """
        Get top N solutions by distance to ideal point (0,0,0)
        
        These are the N "best" solutions overall, regardless of preferences.
        """
        if len(self.cost_pool) == 0:
            return []
        
        # Extract features for all solutions
        all_features = np.array([[s['features'][obj] for obj in self.objectives] 
                                for s in self.cost_pool])
        
        # Normalize to [0, 1] range
        min_vals = all_features.min(axis=0)
        max_vals = all_features.max(axis=0)
        normalized = (all_features - min_vals) / (max_vals - min_vals + 1e-10)
        
        # Calculate distance to ideal point (0,0,0)
        distances = np.sqrt(np.sum(normalized**2, axis=1))
        
        # Select top N by lowest distance
        n = min(n, len(self.cost_pool))  # Don't exceed pool size
        best_indices = np.argsort(distances)[:n]
        
        return [self.cost_pool[i] for i in best_indices]
    
    def normalize_objectives(self, solutions: List[Dict]) -> np.ndarray:
        """Normalize objectives to [0, 1] for fair comparison"""
        if len(solutions) == 0:
            return np.array([])
        
        values = np.array([[s['features'][obj] for obj in self.objectives] 
                          for s in solutions])
        
        normalized = np.zeros_like(values, dtype=float)
        for j in range(len(self.objectives)):
            min_val = values[:, j].min()
            max_val = values[:, j].max()
            if max_val > min_val:
                normalized[:, j] = (values[:, j] - min_val) / (max_val - min_val)
            else:
                normalized[:, j] = 0.0
        
        return normalized
    
    def select_best(self, solutions: List[Dict], preferences: Dict) -> Dict:
        """
        Select best solution from list using weighted Euclidean distance
        
        Args:
            solutions: List of candidate solutions
            preferences: User preference weights
        
        Returns:
            Best matching solution (copy with added metadata)
        """
        if len(solutions) == 0:
            return None
        
        if len(solutions) == 1:
            result = solutions[0].copy()
            result['pareto_distance'] = 0.0
            result['selection_pool_size'] = 1
            return result
        
        # Normalize objectives
        normalized = self.normalize_objectives(solutions)
        
        # Create weight vector from preferences
        weights = np.array([
            preferences['parking_importance'],
            preferences['time_importance'],
            preferences['distance_importance']
        ])
        
        # Calculate weighted Euclidean distance to ideal (0,0,0)
        distances = np.sqrt(np.sum((normalized * weights) ** 2, axis=1))
        
        # Select solution with minimum distance
        best_idx = np.argmin(distances)
        
        # Return copy with metadata
        result = solutions[best_idx].copy()
        result['pareto_distance'] = float(distances[best_idx])
        result['selection_pool_size'] = len(solutions)
        
        return result

print("✓ ParetoAnalyzer class defined")
# Out:
# ✓ ParetoAnalyzer class defined

# %% [markdown]
# ## 4. Data Collector Class

# %%
class CostPoolDataCollector:
    """Two-phase data collector with Pareto Top-N selection"""
    
    def __init__(self, base_url, username, password, model_path, cost_ranges):
        self.base_url = base_url.rstrip('/')
        self.username = username
        self.password = password
        self.cost_ranges = cost_ranges
        
        # Initialize session
        self.session = requests.Session()
        self.session.auth = (username, password)
        self.session.headers.update({
            'Content-Type': 'application/json',
            'Accept': 'application/json'
        })
        
        # Load base model
        with open(model_path, 'r') as f:
            self.base_model = json.load(f)
        
        print(f"✓ Initialized")
        print(f"  Jobs: {len(self.base_model['data']['jobs'])}")
        print(f"  Vehicles: {len(self.base_model['data']['vehicles'])}")
        
        # Data storage
        self.cost_pool = []
        self.training_data = []
    
    # ========================================================================
    # HELPER METHODS
    # ========================================================================
    
    def sample_random_costs(self):
        """Sample random cost parameters (kept for backward compatibility)"""
        costs = {}
        for param, (min_val, max_val) in self.cost_ranges.items():
            costs[param] = np.random.uniform(min_val, max_val)
        
        # Round for cleaner values
        costs['costPerTravelHour'] = round(costs['costPerTravelHour'], 2)
        costs['costPerKm'] = round(costs['costPerKm'], 4)
        costs['parking_multiplier'] = round(costs['parking_multiplier'], 2)
        
        return costs
    
    def sample_diverse_costs(self):
        """Sample costs that create diverse trade-offs across feature space"""
        import random
        
        # Choose a strategy to ensure diversity
        strategy = random.choice(['time_focused', 'distance_focused', 
                                 'parking_focused', 'balanced', 'random'])
        
        if strategy == 'time_focused':
            # Make time VERY expensive → prefer faster routes
            costs = {
                'costPerTravelHour': np.random.uniform(10.0, 20.0),  # High
                'costPerKm': np.random.uniform(0.01, 0.1),           # Low
                'parking_multiplier': np.random.uniform(0.2, 1.0)    # Low-medium
            }
        elif strategy == 'distance_focused':
            # Make distance VERY expensive → prefer shorter routes
            costs = {
                'costPerTravelHour': np.random.uniform(0.5, 2.0),    # Low-medium
                'costPerKm': np.random.uniform(1.0, 2.0),            # High
                'parking_multiplier': np.random.uniform(0.2, 1.0)    # Low-medium
            }
        elif strategy == 'parking_focused':
            # Make parking VERY expensive → avoid difficult parking
            costs = {
                'costPerTravelHour': np.random.uniform(0.5, 2.0),    # Low-medium
                'costPerKm': np.random.uniform(0.01, 0.2),           # Low
                'parking_multiplier': np.random.uniform(5.0, 10.0)   # High
            }
        elif strategy == 'balanced':
            # Moderate costs → balanced solutions
            costs = {
                'costPerTravelHour': np.random.uniform(2.0, 5.0),
                'costPerKm': np.random.uniform(0.1, 0.3),
                'parking_multiplier': np.random.uniform(0.8, 1.5)
            }
        else:  # random
            # Wide random range for exploration
            costs = {
                'costPerTravelHour': np.random.uniform(0.5, 15.0),
                'costPerKm': np.random.uniform(0.01, 1.5),
                'parking_multiplier': np.random.uniform(0.2, 8.0)
            }
        
        # Round for cleaner values
        costs['costPerTravelHour'] = round(costs['costPerTravelHour'], 2)
        costs['costPerKm'] = round(costs['costPerKm'], 4)
        costs['parking_multiplier'] = round(costs['parking_multiplier'], 2)
        
        return costs
    
    # def sample_preferences(self):
    #     """Sample random preferences using Dirichlet distribution"""
    #     # Dirichlet ensures diversity and sum close to ~3
    #     weights = np.random.dirichlet([1, 1, 1])
    #     return {
    #         'parking_importance': float(weights[0]),
    #         'time_importance': float(weights[1]),
    #         'distance_importance': float(weights[2])
    #     }
    
    def sample_preferences(self):
        """Sample with more extreme preferences"""
        import random
        
        # 50% extreme preferences, 50% balanced
        if random.random() < 0.5:
            # Extreme: one dimension dominates
            choice = random.randint(0, 2)
            weights = [0.1, 0.1, 0.1]
            weights[choice] = 0.8
            
            return {
                'parking_importance': weights[0],
                'time_importance': weights[1],
                'distance_importance': weights[2]
            }
        else:
            # Balanced: use Dirichlet
            weights = np.random.dirichlet([1, 1, 1])
            return {
                'parking_importance': float(weights[0]),
                'time_importance': float(weights[1]),
                'distance_importance': float(weights[2])
            }
    
    def apply_costs_to_model(self, costs):
        """Apply cost parameters to model"""
        model = copy.deepcopy(self.base_model)
        
        # Apply vehicle costs
        for vehicle in model['data']['vehicles']:
            if 'definition' in vehicle:
                vehicle['definition']['costPerTravelHour'] = costs['costPerTravelHour']
                vehicle['definition']['costPerKm'] = costs['costPerKm']
        
        # Apply parking multiplier to delivery stops
        for job in model['data']['jobs']:
            for stop in job.get('stops', []):
                if (stop.get('type') == 'SHIPMENT_DELIVERY' and 
                    'parking' in stop and 
                    'cost' in stop['parking'] and 
                    stop['parking']['cost'] > 0):
                    original_cost = stop['parking']['cost']
                    stop['parking']['cost'] = original_cost * costs['parking_multiplier']
        
        return model
    
    def send_to_odl(self, model, model_id):
        """Send model to ODL API"""
        url = f"{self.base_url}/models/{model_id}"
        try:
            response = self.session.put(url, json=model, timeout=30)
            response.raise_for_status()
            return True
        except Exception as e:
            print(f"  ✗ Upload failed: {e}")
            return False
    
    def get_plan(self, model_id):
        """Retrieve plan from ODL API"""
        url = f"{self.base_url}/models/{model_id}/optimiserstate/plan"
        try:
            response = self.session.get(url, timeout=30)
            response.raise_for_status()
            return response.json()
        except Exception as e:
            print(f"  ✗ Get plan failed: {e}")
            return None
    
    def extract_features(self, plan):
        """Extract route features from plan"""
        if not plan or 'vehiclePlans' not in plan:
            return None
        
        features = {
            'total_distance_km': 0.0,
            'total_travel_hours': 0.0,
            'total_cost': 0.0,
            'num_stops': 0,
            'num_vehicles_used': 0,
            'unplanned_jobs': len(plan.get('unplannedJobs', [])),
            'avg_parking_difficulty': 0.0
        }
        
        total_parking_cost = 0.0
        total_stops = 0
        
        for vehicle_plan in plan['vehiclePlans']:
            stops = vehicle_plan.get('plannedStops', [])
            
            if len(stops) > 0:
                features['num_vehicles_used'] += 1
                features['num_stops'] += len(stops)
                total_stops += len(stops)
            
            time_stats = vehicle_plan.get('timeStatistics', {})
            features['total_distance_km'] += time_stats.get('travelMetres', 0) / 1000.0
            features['total_travel_hours'] += time_stats.get('travelSeconds', 0) / 3600.0
            features['total_cost'] += time_stats.get('cost', 0)
            
            breakdown = time_stats.get('optimiserCostBreakdown', {})
            total_parking_cost += breakdown.get('PARKING_COST', 0.0)
        
        if total_stops > 0:
            features['avg_parking_difficulty'] = total_parking_cost / total_stops
        
        # Round
        features['total_distance_km'] = round(features['total_distance_km'], 2)
        features['total_travel_hours'] = round(features['total_travel_hours'], 2)
        features['total_cost'] = round(features['total_cost'], 2)
        features['avg_parking_difficulty'] = round(features['avg_parking_difficulty'], 2)
        
        return features
    
    # ========================================================================
    # PHASE 1: BUILD COST POOL
    # ========================================================================
    
    def build_cost_pool(self, pool_size, wait_seconds, checkpoint_every, pool_file):
        """Phase 1: Generate pool of cost sets with optimized solutions"""
        print(f"\n{'='*60}")
        print(f"PHASE 1: BUILDING COST POOL")
        print(f"{'='*60}")
        print(f"Target: {pool_size} cost sets")
        print(f"Estimated time: {(pool_size * wait_seconds) / 3600:.1f} hours")
        print(f"{'='*60}\n")
        
        start_time = time.time()
        
        try:
            for i in range(1, pool_size + 1):
                print(f"\nCost Set {i}/{pool_size}:")
                
                try:
                    costs = self.sample_diverse_costs()  # Using strategic diverse sampling
                    print(f"  Costs: {costs['costPerTravelHour']:.2f}/h, "
                          f"{costs['costPerKm']:.4f}/km, parking×{costs['parking_multiplier']:.2f}")
                    
                    model = self.apply_costs_to_model(costs)
                    model_id = f"cost_pool_{i}"
                    
                    if not self.send_to_odl(model, model_id):
                        continue
                    
                    print(f"  ✓ Uploaded, waiting {wait_seconds}s...")
                    time.sleep(wait_seconds)
                    
                    plan = self.get_plan(model_id)
                    features = self.extract_features(plan)
                    
                    if features is None:
                        print(f"  ✗ Failed to extract features")
                        continue
                    
                    print(f"  Features: {features['total_distance_km']:.1f}km, "
                          f"{features['total_travel_hours']:.1f}h, "
                          f"parking={features['avg_parking_difficulty']:.1f}, "
                          f"unplanned={features['unplanned_jobs']}")
                    
                    self.cost_pool.append({
                        'pool_id': i,
                        'costs': costs,
                        'features': features,
                        'timestamp': datetime.now().isoformat()
                    })
                    
                    print(f"  ✓ Added (total: {len(self.cost_pool)})")
                    
                    if i % checkpoint_every == 0:
                        self.save_cost_pool(pool_file)
                        elapsed = time.time() - start_time
                        remaining = ((pool_size - i) * elapsed / i)
                        print(f"\n  CHECKPOINT: {len(self.cost_pool)}/{pool_size} | "
                              f"Elapsed: {elapsed/3600:.1f}h | Remaining: {remaining/3600:.1f}h\n")
                
                except Exception as e:
                    print(f"  ✗ Error: {e}")
        
        except KeyboardInterrupt:
            print(f"\n\nInterrupted! Pool has {len(self.cost_pool)} entries")
        
        self.save_cost_pool(pool_file)
        
        elapsed = time.time() - start_time
        print(f"\n{'='*60}")
        print(f"PHASE 1 COMPLETE")
        print(f"{'='*60}")
        print(f"Cost pool: {len(self.cost_pool)} solutions")
        print(f"Time: {elapsed/3600:.1f} hours")
        print(f"Saved to: {pool_file}")
        print(f"{'='*60}\n")
    
    def save_cost_pool(self, pool_file):
        """Save cost pool to file"""
        with open(pool_file, 'w') as f:
            json.dump(self.cost_pool, f, indent=2)
        print(f"  💾 Saved to {pool_file}")
    
    def load_cost_pool(self, pool_file):
        """Load cost pool from file"""
        try:
            with open(pool_file, 'r') as f:
                self.cost_pool = json.load(f)
            print(f"✓ Loaded {len(self.cost_pool)} solutions from {pool_file}")
            return True
        except FileNotFoundError:
            print(f"✗ File not found: {pool_file}")
            return False
    
    # ========================================================================
    # PHASE 2: MATCH PREFERENCES TO POOL (PARETO TOP-N)
    # ========================================================================
    
    def find_best_match(self, preferences, top_n=30):
        """
        Find best match using Pareto Top-N selection
        
        Process:
        1. Get top N solutions (closest to ideal point)
        2. Select best using weighted Pareto evaluation
        """
        if len(self.cost_pool) == 0:
            return None
        
        analyzer = ParetoAnalyzer(self.cost_pool)
        top_solutions = analyzer.get_top_n_solutions(n=top_n)
        best_match = analyzer.select_best(top_solutions, preferences)
        
        return best_match
    
    def generate_training_samples(self, n_samples, top_n, top_k):
        """Phase 2: Generate training samples using top-K matches per preference"""
        if len(self.cost_pool) == 0:
            print("✗ Cost pool is empty! Load or build first.")
            return
        
        print(f"\n{'='*60}")
        print(f"PHASE 2: GENERATING TRAINING SAMPLES")
        print(f"{'='*60}")
        print(f"Cost pool: {len(self.cost_pool)} solutions")
        print(f"Preferences: {n_samples}")
        print(f"Top-N selection: {top_n}")
        print(f"Top-K per preference: {top_k}")
        print(f"Total samples: {n_samples * top_k}")
        print(f"{'='*60}\n")
        
        self.training_data = []
        analyzer = ParetoAnalyzer(self.cost_pool)
        
        for i in range(1, n_samples + 1):
            print(f"\rPreference {i}/{n_samples}", end='', flush=True)
            
            preferences = self.sample_preferences()
            top_solutions = analyzer.get_top_n_solutions(n=top_n)
            
            # Calculate distances for all top N
            normalized = analyzer.normalize_objectives(top_solutions)
            weights = np.array([
                preferences['parking_importance'],
                preferences['time_importance'],
                preferences['distance_importance']
            ])
            distances = np.sqrt(np.sum((normalized * weights) ** 2, axis=1))
            
            # Get top K matches (not just best 1!)
            top_k_indices = np.argsort(distances)[:top_k]
            
            # Create K samples from same preference
            for rank, idx in enumerate(top_k_indices, 1):
                solution = top_solutions[idx]
                
                sample = {
                    'sample_id': len(self.training_data) + 1,
                    'preferences': preferences,
                    'costs': solution['costs'],
                    'features': solution['features'],
                    'metadata': {
                        'pool_id': solution['pool_id'],
                        'rank_for_preference': rank,
                        'pareto_distance': float(distances[idx]),
                        'selection_pool_size': top_n,
                        'timestamp': datetime.now().isoformat()
                    }
                }
                
                self.training_data.append(sample)
        
        # Create timestamped output folder
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        output_folder = f"training_data_{timestamp}"
        os.makedirs(output_folder, exist_ok=True)
        
        # Save training data to folder
        output_file = os.path.join(output_folder, "training_data.json")
        with open(output_file, 'w') as f:
            json.dump(self.training_data, f, indent=2)
        
        # Store folder path for visualization
        self.output_folder = output_folder
        
        print(f"\n\n{'='*60}")
        print(f"PHASE 2 COMPLETE")
        print(f"{'='*60}")
        print(f"Generated: {len(self.training_data)} samples")
        print(f"From: {n_samples} preferences × top-{top_k}")
        print(f"Saved to: {output_folder}/")
        print(f"  - training_data.json")
        
        # Statistics
        pool_ids = [s['metadata']['pool_id'] for s in self.training_data]
        unique_ids = len(set(pool_ids))
        print(f"\nDiversity: {unique_ids} unique solutions used")
        print(f"Avg samples per solution: {len(self.training_data) / unique_ids:.1f}")
        print(f"{'='*60}\n")

print("✓ CostPoolDataCollector class defined")
# Out:
# ✓ CostPoolDataCollector class defined

# %% [markdown]
# ## 5. Initialize Collector

# %%
collector = CostPoolDataCollector(
    base_url=BASE_URL,
    username=USERNAME,
    password=PASSWORD,
    model_path=MODEL_PATH,
    cost_ranges=COST_RANGES
)
# Out:
# ✓ Initialized
#   Jobs: 106
#   Vehicles: 26

# %% [markdown]
# ## 6. Phase 1: Build Cost Pool (or Load Existing)
#
# **If you already have cost_pool.json, skip to Phase 2!**

# %%
# Option A: Load existing pool
collector.load_cost_pool(POOL_FILE)
# Out:
# ✓ Loaded 200 solutions from cost_pool.json
# True

# %%
# Option B: Build new pool (takes ~6 hours for 200 samples at 30s each)
collector.build_cost_pool(
    pool_size=POOL_SIZE,
    wait_seconds=WAIT_SECONDS,
    checkpoint_every=CHECKPOINT_EVERY,
    pool_file=POOL_FILE
)
# Out:
# ============================================================
# PHASE 1: BUILDING COST POOL
# ============================================================
# Target: 200 cost sets
# Estimated time: 3.3 hours
# ============================================================
#
#
# Cost Set 1/200:
#   Costs: 1.19/h, 1.9103/km, parking×0.56
#   ✗ Upload failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# Cost Set 2/200:
#   Costs: 4.86/h, 0.2176/km, parking×1.43
#   ✓ Uploaded, waiting 60s...
#   Features: 1019.6km, 33.8h, parking=299.4, unplanned=2
#   ✓ Added (total: 11)
#
# Cost Set 3/200:
#   Costs: 0.58/h, 1.3745/km, parking×4.24
#   ✓ Uploaded, waiting 60s...
#   Features: 929.5km, 32.7h, parking=245.0, unplanned=2
#   ✓ Added (total: 12)
#
# Cost Set 4/200:
#   Costs: 4.46/h, 0.6801/km, parking×2.94
#   ✓ Uploaded, waiting 60s...
#   Features: 1034.0km, 33.9h, parking=1372.0, unplanned=2
#   ✓ Added (total: 13)
#
# Cost Set 5/200:
#   Costs: 4.24/h, 0.7482/km, parking×6.26
#   ✓ Uploaded, waiting 60s...
#   Features: 936.4km, 32.9h, parking=1309.5, unplanned=2
#   ✓ Added (total: 14)
#
# Cost Set 6/200:
#   Costs: 14.53/h, 0.0534/km, parking×0.53
#   ✓ Uploaded, waiting 60s...
#   Features: 934.7km, 32.8h, parking=111.8, unplanned=2
#   ✓ Added (total: 15)
#
# Cost Set 7/200:
#   Costs: 10.65/h, 0.0968/km, parking×0.55
#   ✓ Uploaded, waiting 60s...
#   Features: 907.9km, 32.4h, parking=173.8, unplanned=2
#   ✓ Added (total: 16)
#
# Cost Set 8/200:
#   Costs: 1.33/h, 0.1080/km, parking×9.08
#   ✓ Uploaded, waiting 60s...
#   Features: 918.8km, 32.7h, parking=820.1, unplanned=2
#   ✓ Added (total: 17)
#
# Cost Set 9/200:
#   Costs: 5.00/h, 0.2938/km, parking×1.20
#   ✓ Uploaded, waiting 60s...
#   Features: 953.6km, 33.2h, parking=251.3, unplanned=2
#   ✓ Added (total: 18)
#
# Cost Set 10/200:
#   Costs: 0.75/h, 0.0276/km, parking×5.57
#   ✓ Uploaded, waiting 60s...
#   Features: 915.0km, 32.6h, parking=194.6, unplanned=2
#   ✓ Added (total: 19)
#   💾 Saved to cost_pool.json
#
#   CHECKPOINT: 19/200 | Elapsed: 0.2h | Remaining: 2.9h
#
#
# Cost Set 11/200:
#   Costs: 0.73/h, 1.7196/km, parking×0.64
#   ✓ Uploaded, waiting 60s...
#   Features: 1015.9km, 33.7h, parking=67.9, unplanned=2
#   ✓ Added (total: 20)
#
# Cost Set 12/200:
#   Costs: 1.89/h, 1.7418/km, parking×0.43
#   ✓ Uploaded, waiting 60s...
#   Features: 971.4km, 34.1h, parking=184.3, unplanned=2
#   ✓ Added (total: 21)
#
# Cost Set 13/200:
#   Costs: 19.05/h, 0.0407/km, parking×0.92
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=921.1, unplanned=20
#   ✓ Added (total: 22)
#
# Cost Set 14/200:
#   Costs: 2.16/h, 0.1876/km, parking×1.31
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=628.1, unplanned=20
#   ✓ Added (total: 23)
#
# Cost Set 15/200:
#   Costs: 12.45/h, 0.0493/km, parking×0.91
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=559.1, unplanned=20
#   ✓ Added (total: 24)
#
# Cost Set 16/200:
#   Costs: 3.34/h, 0.2816/km, parking×1.47
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=739.1, unplanned=20
#   ✓ Added (total: 25)
#
# Cost Set 17/200:
#   Costs: 11.10/h, 0.0880/km, parking×0.60
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=952.6, unplanned=20
#   ✓ Added (total: 26)
#
# Cost Set 18/200:
#   Costs: 4.66/h, 0.1726/km, parking×0.85
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=969.3, unplanned=20
#   ✓ Added (total: 27)
#
# Cost Set 19/200:
#   Costs: 3.74/h, 0.1424/km, parking×1.40
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=454.3, unplanned=20
#   ✓ Added (total: 28)
#
# Cost Set 20/200:
#   Costs: 1.71/h, 0.0201/km, parking×7.61
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=973.5, unplanned=20
#   ✓ Added (total: 29)
#   💾 Saved to cost_pool.json
#
#   CHECKPOINT: 29/200 | Elapsed: 0.3h | Remaining: 2.9h
#
#
# Cost Set 21/200:
#   Costs: 3.04/h, 0.2455/km, parking×0.93
#   ✓ Uploaded, waiting 60s...
#   Features: 1251.8km, 38.4h, parking=199.2, unplanned=2
#   ✓ Added (total: 30)
#
# Cost Set 22/200:
#   Costs: 4.57/h, 0.1597/km, parking×0.98
#   ✓ Uploaded, waiting 60s...
#   Features: 1079.3km, 35.5h, parking=209.7, unplanned=3
#   ✓ Added (total: 31)
#
# Cost Set 23/200:
#   Costs: 1.59/h, 1.1896/km, parking×1.14
#   ✓ Uploaded, waiting 60s...
#   Features: 926.7km, 33.2h, parking=244.0, unplanned=2
#   ✓ Added (total: 32)
#
# Cost Set 24/200:
#   Costs: 3.78/h, 0.2416/km, parking×1.48
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=726.3, unplanned=20
#   ✓ Added (total: 33)
#
# Cost Set 25/200:
#   Costs: 3.15/h, 0.1935/km, parking×1.19
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=54.6, unplanned=20
#   ✓ Added (total: 34)
#
# Cost Set 26/200:
#   Costs: 12.35/h, 0.0516/km, parking×0.62
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=728.6, unplanned=20
#   ✓ Added (total: 35)
#
# Cost Set 27/200:
#   Costs: 1.06/h, 1.2950/km, parking×0.21
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=230.3, unplanned=20
#   ✓ Added (total: 36)
#
# Cost Set 28/200:
#   Costs: 14.43/h, 0.0470/km, parking×0.85
#   ✓ Uploaded, waiting 60s...
#   Features: 1139.0km, 36.3h, parking=178.8, unplanned=2
#   ✓ Added (total: 37)
#
# Cost Set 29/200:
#   Costs: 11.05/h, 0.0547/km, parking×0.31
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=136.1, unplanned=20
#   ✓ Added (total: 38)
#
# Cost Set 30/200:
#   Costs: 1.83/h, 0.1279/km, parking×6.74
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=536.0, unplanned=20
#   ✓ Added (total: 39)
#   💾 Saved to cost_pool.json
#
#   CHECKPOINT: 39/200 | Elapsed: 0.5h | Remaining: 2.8h
#
#
# Cost Set 31/200:
#   Costs: 3.84/h, 0.2040/km, parking×1.37
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.6km, 30.4h, parking=115.4, unplanned=20
#   ✓ Added (total: 40)
#
# Cost Set 32/200:
#   Costs: 5.27/h, 0.7907/km, parking×0.68
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=827.0, unplanned=20
#   ✓ Added (total: 41)
#
# Cost Set 33/200:
#   Costs: 11.40/h, 0.0430/km, parking×0.85
#   ✓ Uploaded, waiting 60s...
#   Features: 1277.9km, 38.4h, parking=180.6, unplanned=2
#   ✓ Added (total: 42)
#
# Cost Set 34/200:
#   Costs: 1.28/h, 1.4502/km, parking×0.95
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=952.4, unplanned=20
#   ✓ Added (total: 43)
#
# Cost Set 35/200:
#   Costs: 2.93/h, 0.2185/km, parking×1.00
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=94.4, unplanned=20
#   ✓ Added (total: 44)
#
# Cost Set 36/200:
#   Costs: 14.21/h, 1.4229/km, parking×1.89
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=1040.3, unplanned=20
#   ✓ Added (total: 45)
#
# Cost Set 37/200:
#   Costs: 17.51/h, 0.0467/km, parking×0.26
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=845.9, unplanned=20
#   ✓ Added (total: 46)
#
# Cost Set 38/200:
#   Costs: 1.56/h, 1.6824/km, parking×0.26
#   ✓ Uploaded, waiting 60s...
#   Features: 978.2km, 33.9h, parking=55.7, unplanned=2
#   ✓ Added (total: 47)
#
# Cost Set 39/200:
#   Costs: 1.10/h, 0.0370/km, parking×5.34
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=481.7, unplanned=20
#   ✓ Added (total: 48)
#
# Cost Set 40/200:
#   Costs: 0.79/h, 0.1732/km, parking×8.19
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=324.7, unplanned=20
#   ✓ Added (total: 49)
#   💾 Saved to cost_pool.json
#
#   CHECKPOINT: 49/200 | Elapsed: 0.7h | Remaining: 2.6h
#
#
# Cost Set 41/200:
#   Costs: 1.27/h, 0.1972/km, parking×7.66
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=580.0, unplanned=20
#   ✓ Added (total: 50)
#
# Cost Set 42/200:
#   Costs: 3.40/h, 0.2289/km, parking×1.28
#   ✓ Uploaded, waiting 60s...
#   Features: 1264.0km, 38.9h, parking=271.0, unplanned=2
#   ✓ Added (total: 51)
#
# Cost Set 43/200:
#   Costs: 0.78/h, 0.0718/km, parking×6.08
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=778.7, unplanned=20
#   ✓ Added (total: 52)
#
# Cost Set 44/200:
#   Costs: 4.14/h, 0.2504/km, parking×1.35
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.6km, 30.4h, parking=218.0, unplanned=20
#   ✓ Added (total: 53)
#
# Cost Set 45/200:
#   Costs: 0.56/h, 1.6195/km, parking×0.63
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=96.4, unplanned=20
#   ✓ Added (total: 54)
#
# Cost Set 46/200:
#   Costs: 0.75/h, 0.0948/km, parking×7.09
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=209.4, unplanned=20
#   ✓ Added (total: 55)
#
# Cost Set 47/200:
#   Costs: 12.26/h, 0.0891/km, parking×0.73
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=320.5, unplanned=20
#   ✓ Added (total: 56)
#
# Cost Set 48/200:
#   Costs: 16.08/h, 0.0392/km, parking×0.53
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=247.3, unplanned=20
#   ✓ Added (total: 57)
#
# Cost Set 49/200:
#   Costs: 0.83/h, 0.0744/km, parking×8.41
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=548.5, unplanned=20
#   ✓ Added (total: 58)
#
# Cost Set 50/200:
#   Costs: 9.37/h, 1.1885/km, parking×3.64
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=188.4, unplanned=20
#   ✓ Added (total: 59)
#   💾 Saved to cost_pool.json
#
#   CHECKPOINT: 59/200 | Elapsed: 0.8h | Remaining: 2.5h
#
#
# Cost Set 51/200:
#   Costs: 2.83/h, 0.1872/km, parking×1.44
#   ✓ Uploaded, waiting 60s...
#   Features: 1236.1km, 37.8h, parking=301.4, unplanned=2
#   ✓ Added (total: 60)
#
# Cost Set 52/200:
#   Costs: 1.95/h, 0.1803/km, parking×6.91
#   ✓ Uploaded, waiting 60s...
#   Features: 1228.8km, 38.0h, parking=1492.8, unplanned=3
#   ✓ Added (total: 61)
#
# Cost Set 53/200:
#   Costs: 14.96/h, 0.3448/km, parking×5.93
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=374.9, unplanned=20
#   ✓ Added (total: 62)
#
# Cost Set 54/200:
#   Costs: 0.59/h, 0.1076/km, parking×9.44
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=439.8, unplanned=20
#   ✓ Added (total: 63)
#
# Cost Set 55/200:
#   Costs: 17.99/h, 0.0852/km, parking×0.84
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=50.5, unplanned=20
#   ✓ Added (total: 64)
#
# Cost Set 56/200:
#   Costs: 3.26/h, 0.1418/km, parking×0.98
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=339.2, unplanned=20
#   ✓ Added (total: 65)
#
# Cost Set 57/200:
#   Costs: 1.31/h, 0.1856/km, parking×7.41
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=54.7, unplanned=20
#   ✓ Added (total: 66)
#
# Cost Set 58/200:
#   Costs: 12.26/h, 0.0445/km, parking×0.85
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=309.8, unplanned=20
#   ✓ Added (total: 67)
#
# Cost Set 59/200:
#   Costs: 10.83/h, 0.0991/km, parking×0.79
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=594.6, unplanned=20
#   ✓ Added (total: 68)
#
# Cost Set 60/200:
#   Costs: 4.95/h, 0.1691/km, parking×0.93
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=835.3, unplanned=20
#   ✓ Added (total: 69)
#   💾 Saved to cost_pool.json
#
#   CHECKPOINT: 69/200 | Elapsed: 1.0h | Remaining: 2.3h
#
#
# Cost Set 61/200:
#   Costs: 3.91/h, 0.1627/km, parking×1.21
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=58.8, unplanned=20
#   ✓ Added (total: 70)
#
# Cost Set 62/200:
#   Costs: 1.08/h, 1.5372/km, parking×0.35
#   ✓ Uploaded, waiting 60s...
#   Features: 960.5km, 33.3h, parking=74.1, unplanned=2
#   ✓ Added (total: 71)
#
# Cost Set 63/200:
#   Costs: 13.50/h, 1.2425/km, parking×5.24
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=738.9, unplanned=20
#   ✓ Added (total: 72)
#
# Cost Set 64/200:
#   Costs: 1.21/h, 1.6412/km, parking×0.74
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=684.6, unplanned=20
#   ✓ Added (total: 73)
#
# Cost Set 65/200:
#   Costs: 4.05/h, 0.2887/km, parking×0.98
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=180.1, unplanned=20
#   ✓ Added (total: 74)
#
# Cost Set 66/200:
#   Costs: 3.94/h, 0.1762/km, parking×0.89
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=188.5, unplanned=20
#   ✓ Added (total: 75)
#
# Cost Set 67/200:
#   Costs: 4.01/h, 0.2824/km, parking×1.19
#   ✓ Uploaded, waiting 60s...
#   Features: 1272.2km, 37.9h, parking=251.6, unplanned=3
#   ✓ Added (total: 76)
#
# Cost Set 68/200:
#   Costs: 1.06/h, 0.3806/km, parking×4.88
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.6km, 30.4h, parking=391.6, unplanned=20
#   ✓ Added (total: 77)
#
# Cost Set 69/200:
#   Costs: 1.58/h, 1.0158/km, parking×0.52
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=50.4, unplanned=20
#   ✓ Added (total: 78)
#
# Cost Set 70/200:
#   Costs: 15.77/h, 0.0391/km, parking×0.64
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=176.0, unplanned=20
#   ✓ Added (total: 79)
#   💾 Saved to cost_pool.json
#
#   CHECKPOINT: 79/200 | Elapsed: 1.2h | Remaining: 2.2h
#
#
# Cost Set 71/200:
#   Costs: 10.92/h, 1.0429/km, parking×4.17
#   ✓ Uploaded, waiting 60s...
#   Features: 935.0km, 33.1h, parking=871.2, unplanned=3
#   ✓ Added (total: 80)
#
# Cost Set 72/200:
#   Costs: 4.95/h, 0.2215/km, parking×1.13
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=192.6, unplanned=20
#   ✓ Added (total: 81)
#
# Cost Set 73/200:
#   Costs: 0.56/h, 1.3994/km, parking×0.27
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.6km, 30.4h, parking=799.8, unplanned=20
#   ✓ Added (total: 82)
#
# Cost Set 74/200:
#   Costs: 3.88/h, 0.1153/km, parking×1.18
#   ✓ Uploaded, waiting 60s...
#   Features: 1029.6km, 34.8h, parking=247.1, unplanned=2
#   ✓ Added (total: 83)
#
# Cost Set 75/200:
#   Costs: 13.07/h, 0.0584/km, parking×0.97
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=958.9, unplanned=20
#   ✓ Added (total: 84)
#
# Cost Set 76/200:
#   Costs: 1.30/h, 0.0506/km, parking×6.40
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=768.3, unplanned=20
#   ✓ Added (total: 85)
#
# Cost Set 77/200:
#   Costs: 1.52/h, 1.5061/km, parking×0.68
#   ✓ Uploaded, waiting 60s...
#   Features: 924.8km, 32.7h, parking=142.3, unplanned=2
#   ✓ Added (total: 86)
#
# Cost Set 78/200:
#   Costs: 0.63/h, 0.9353/km, parking×1.23
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=211.5, unplanned=20
#   ✓ Added (total: 87)
#
# Cost Set 79/200:
#   Costs: 0.57/h, 0.1435/km, parking×6.29
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=146.7, unplanned=20
#   ✓ Added (total: 88)
#
# Cost Set 80/200:
#   Costs: 18.50/h, 0.0390/km, parking×0.49
#   ✓ Uploaded, waiting 60s...
#   Features: 965.3km, 33.8h, parking=105.0, unplanned=2
#   ✓ Added (total: 89)
#   💾 Saved to cost_pool.json
#
#   CHECKPOINT: 89/200 | Elapsed: 1.3h | Remaining: 2.0h
#
#
# Cost Set 81/200:
#   Costs: 9.72/h, 0.2455/km, parking×5.55
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.6km, 30.4h, parking=812.4, unplanned=20
#   ✓ Added (total: 90)
#
# Cost Set 82/200:
#   Costs: 2.26/h, 0.2212/km, parking×0.84
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=1015.3, unplanned=20
#   ✓ Added (total: 91)
#
# Cost Set 83/200:
#   Costs: 3.00/h, 0.2564/km, parking×1.44
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=477.5, unplanned=20
#   ✓ Added (total: 92)
#
# Cost Set 84/200:
#   Costs: 4.92/h, 0.1779/km, parking×0.86
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=527.8, unplanned=20
#   ✓ Added (total: 93)
#
# Cost Set 85/200:
#   Costs: 19.48/h, 0.0944/km, parking×0.91
#   ✓ Uploaded, waiting 60s...
#   Features: 1068.8km, 35.0h, parking=191.3, unplanned=3
#   ✓ Added (total: 94)
#
# Cost Set 86/200:
#   Costs: 17.94/h, 0.0112/km, parking×0.60
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=314.1, unplanned=20
#   ✓ Added (total: 95)
#
# Cost Set 87/200:
#   Costs: 0.72/h, 1.6899/km, parking×0.75
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=464.8, unplanned=20
#   ✓ Added (total: 96)
#
# Cost Set 88/200:
#   Costs: 0.76/h, 1.3367/km, parking×0.53
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=301.7, unplanned=20
#   ✓ Added (total: 97)
#
# Cost Set 89/200:
#   Costs: 10.50/h, 0.0561/km, parking×0.74
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=353.9, unplanned=20
#   ✓ Added (total: 98)
#
# Cost Set 90/200:
#   Costs: 2.99/h, 0.2399/km, parking×1.12
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=310.1, unplanned=20
#   ✓ Added (total: 99)
#   💾 Saved to cost_pool.json
#
#   CHECKPOINT: 99/200 | Elapsed: 1.5h | Remaining: 1.8h
#
#
# Cost Set 91/200:
#   Costs: 13.37/h, 0.5884/km, parking×1.22
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=693.1, unplanned=20
#   ✓ Added (total: 100)
#
# Cost Set 92/200:
#   Costs: 1.42/h, 0.0799/km, parking×9.00
#   ✓ Uploaded, waiting 60s...
#   Features: 1379.3km, 40.2h, parking=1904.0, unplanned=2
#   ✓ Added (total: 101)
#
# Cost Set 93/200:
#   Costs: 1.49/h, 0.1896/km, parking×8.11
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=554.7, unplanned=20
#   ✓ Added (total: 102)
#
# Cost Set 94/200:
#   Costs: 3.10/h, 0.1791/km, parking×1.21
#   ✓ Uploaded, waiting 60s...
#   Features: 1228.9km, 37.8h, parking=256.2, unplanned=2
#   ✓ Added (total: 103)
#
# Cost Set 95/200:
#   Costs: 13.53/h, 1.1449/km, parking×6.92
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=228.4, unplanned=20
#   ✓ Added (total: 104)
#
# Cost Set 96/200:
#   Costs: 1.37/h, 0.0193/km, parking×5.76
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=766.4, unplanned=20
#   ✓ Added (total: 105)
#
# Cost Set 97/200:
#   Costs: 1.24/h, 1.4968/km, parking×0.59
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=519.2, unplanned=20
#   ✓ Added (total: 106)
#
# Cost Set 98/200:
#   Costs: 1.73/h, 0.3637/km, parking×6.23
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=540.3, unplanned=20
#   ✓ Added (total: 107)
#
# Cost Set 99/200:
#   Costs: 4.74/h, 0.1565/km, parking×0.88
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=515.1, unplanned=20
#   ✓ Added (total: 108)
#
# Cost Set 100/200:
#   Costs: 1.07/h, 0.0848/km, parking×6.79
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=347.6, unplanned=20
#   ✓ Added (total: 109)
#   💾 Saved to cost_pool.json
#
#   CHECKPOINT: 109/200 | Elapsed: 1.7h | Remaining: 1.7h
#
#
# Cost Set 101/200:
#   Costs: 1.64/h, 1.2626/km, parking×0.44
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.6km, 30.4h, parking=990.3, unplanned=20
#   ✓ Added (total: 110)
#
# Cost Set 102/200:
#   Costs: 0.73/h, 1.4685/km, parking×0.21
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=613.3, unplanned=20
#   ✓ Added (total: 111)
#
# Cost Set 103/200:
#   Costs: 1.23/h, 0.0594/km, parking×6.40
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=85.9, unplanned=20
#   ✓ Added (total: 112)
#
# Cost Set 104/200:
#   Costs: 3.02/h, 0.3253/km, parking×5.82
#   ✓ Uploaded, waiting 60s...
#   Features: 1183.0km, 37.5h, parking=1245.4, unplanned=2
#   ✓ Added (total: 113)
#
# Cost Set 105/200:
#   Costs: 3.80/h, 0.2201/km, parking×0.95
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=125.8, unplanned=20
#   ✓ Added (total: 114)
#
# Cost Set 106/200:
#   Costs: 13.36/h, 0.0959/km, parking×0.86
#   ✓ Uploaded, waiting 60s...
#   Features: 948.2km, 33.2h, parking=180.8, unplanned=2
#   ✓ Added (total: 115)
#
# Cost Set 107/200:
#   Costs: 2.31/h, 0.2521/km, parking×1.42
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=559.2, unplanned=20
#   ✓ Added (total: 116)
#
# Cost Set 108/200:
#   Costs: 4.70/h, 0.1976/km, parking×1.19
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=736.9, unplanned=20
#   ✓ Added (total: 117)
#
# Cost Set 109/200:
#   Costs: 10.89/h, 1.1517/km, parking×3.75
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=454.4, unplanned=20
#   ✓ Added (total: 118)
#
# Cost Set 110/200:
#   Costs: 1.00/h, 1.7718/km, parking×0.66
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=929.6, unplanned=20
#   ✓ Added (total: 119)
#   💾 Saved to cost_pool.json
#
#   CHECKPOINT: 119/200 | Elapsed: 1.8h | Remaining: 1.5h
#
#
# Cost Set 111/200:
#   Costs: 11.04/h, 1.3147/km, parking×6.23
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=550.8, unplanned=20
#   ✓ Added (total: 120)
#
# Cost Set 112/200:
#   Costs: 3.71/h, 0.1770/km, parking×0.88
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=634.3, unplanned=20
#   ✓ Added (total: 121)
#
# Cost Set 113/200:
#   Costs: 18.65/h, 0.0626/km, parking×0.51
#   ✓ Uploaded, waiting 60s...
#   Features: 1022.1km, 34.9h, parking=109.2, unplanned=2
#   ✓ Added (total: 122)
#
# Cost Set 114/200:
#   Costs: 8.34/h, 0.4856/km, parking×0.62
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=965.0, unplanned=20
#   ✓ Added (total: 123)
#
# Cost Set 115/200:
#   Costs: 16.16/h, 0.0801/km, parking×0.80
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=908.5, unplanned=20
#   ✓ Added (total: 124)
#
# Cost Set 116/200:
#   Costs: 1.14/h, 0.1954/km, parking×5.14
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=421.0, unplanned=20
#   ✓ Added (total: 125)
#
# Cost Set 117/200:
#   Costs: 2.39/h, 0.2176/km, parking×1.41
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=554.8, unplanned=20
#   ✓ Added (total: 126)
#
# Cost Set 118/200:
#   Costs: 1.90/h, 0.1090/km, parking×7.26
#   ✓ Uploaded, waiting 60s...
#   Features: 1010.2km, 34.1h, parking=1518.5, unplanned=2
#   ✓ Added (total: 127)
#
# Cost Set 119/200:
#   Costs: 4.26/h, 0.1626/km, parking×0.83
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=701.4, unplanned=20
#   ✓ Added (total: 128)
#
# Cost Set 120/200:
#   Costs: 13.88/h, 0.3254/km, parking×2.23
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=908.5, unplanned=20
#   ✓ Added (total: 129)
#   💾 Saved to cost_pool.json
#
#   CHECKPOINT: 129/200 | Elapsed: 2.0h | Remaining: 1.3h
#
#
# Cost Set 121/200:
#   Costs: 1.91/h, 0.5498/km, parking×2.58
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=990.1, unplanned=20
#   ✓ Added (total: 130)
#
# Cost Set 122/200:
#   Costs: 4.35/h, 0.1162/km, parking×0.90
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=975.5, unplanned=20
#   ✓ Added (total: 131)
#
# Cost Set 123/200:
#   Costs: 13.52/h, 0.0982/km, parking×0.71
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=649.1, unplanned=20
#   ✓ Added (total: 132)
#
# Cost Set 124/200:
#   Costs: 0.78/h, 1.7793/km, parking×0.54
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=826.9, unplanned=20
#   ✓ Added (total: 133)
#
# Cost Set 125/200:
#   Costs: 1.17/h, 1.8311/km, parking×0.58
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=533.8, unplanned=20
#   ✓ Added (total: 134)
#
# Cost Set 126/200:
#   Costs: 14.67/h, 0.0132/km, parking×0.28
#   ✓ Uploaded, waiting 60s...
#   Features: 1168.0km, 37.4h, parking=61.0, unplanned=2
#   ✓ Added (total: 135)
#
# Cost Set 127/200:
#   Costs: 0.89/h, 0.1265/km, parking×8.82
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.6km, 30.4h, parking=383.2, unplanned=20
#   ✓ Added (total: 136)
#
# Cost Set 128/200:
#   Costs: 14.27/h, 0.0544/km, parking×0.67
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=971.3, unplanned=20
#   ✓ Added (total: 137)
#
# Cost Set 129/200:
#   Costs: 1.03/h, 0.0966/km, parking×6.79
#   ✓ Uploaded, waiting 60s...
#   Features: 1008.4km, 34.5h, parking=1436.4, unplanned=2
#   ✓ Added (total: 138)
#
# Cost Set 130/200:
#   Costs: 6.14/h, 0.8501/km, parking×2.79
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=251.4, unplanned=20
#   ✓ Added (total: 139)
#   💾 Saved to cost_pool.json
#
#   CHECKPOINT: 139/200 | Elapsed: 2.2h | Remaining: 1.2h
#
#
# Cost Set 131/200:
#   Costs: 15.69/h, 0.0252/km, parking×0.54
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=994.5, unplanned=20
#   ✓ Added (total: 140)
#
# Cost Set 132/200:
#   Costs: 0.75/h, 0.1733/km, parking×8.13
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=986.0, unplanned=20
#   ✓ Added (total: 141)
#
# Cost Set 133/200:
#   Costs: 3.68/h, 0.1610/km, parking×1.14
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=665.8, unplanned=20
#   ✓ Added (total: 142)
#
# Cost Set 134/200:
#   Costs: 14.93/h, 1.2334/km, parking×0.32
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=140.3, unplanned=20
#   ✓ Added (total: 143)
#
# Cost Set 135/200:
#   Costs: 1.47/h, 1.1492/km, parking×0.45
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=973.6, unplanned=20
#   ✓ Added (total: 144)
#
# Cost Set 136/200:
#   Costs: 1.82/h, 0.1346/km, parking×8.71
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=651.1, unplanned=20
#   ✓ Added (total: 145)
#
# Cost Set 137/200:
#   Costs: 2.18/h, 0.1706/km, parking×1.27
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=577.8, unplanned=20
#   ✓ Added (total: 146)
#
# Cost Set 138/200:
#   Costs: 0.65/h, 1.7059/km, parking×0.77
#   ✓ Uploaded, waiting 60s...
#   Features: 993.4km, 34.6h, parking=164.8, unplanned=2
#   ✓ Added (total: 147)
#
# Cost Set 139/200:
#   Costs: 6.76/h, 1.1669/km, parking×5.55
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=190.5, unplanned=20
#   ✓ Added (total: 148)
#
# Cost Set 140/200:
#   Costs: 13.46/h, 0.0424/km, parking×0.50
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=435.6, unplanned=20
#   ✓ Added (total: 149)
#   💾 Saved to cost_pool.json
#
#   CHECKPOINT: 149/200 | Elapsed: 2.3h | Remaining: 1.0h
#
#
# Cost Set 141/200:
#   Costs: 10.98/h, 0.0899/km, parking×0.55
#   ✓ Uploaded, waiting 60s...
#   Features: 1360.8km, 39.6h, parking=117.1, unplanned=2
#   ✓ Added (total: 150)
#
# Cost Set 142/200:
#   Costs: 1.25/h, 1.7118/km, parking×0.29
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=418.9, unplanned=20
#   ✓ Added (total: 151)
#
# Cost Set 143/200:
#   Costs: 19.67/h, 0.0300/km, parking×0.36
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=732.7, unplanned=20
#   ✓ Added (total: 152)
#
# Cost Set 144/200:
#   Costs: 1.53/h, 0.1205/km, parking×5.70
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=573.6, unplanned=20
#   ✓ Added (total: 153)
#
# Cost Set 145/200:
#   Costs: 12.11/h, 0.7315/km, parking×5.90
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=389.6, unplanned=20
#   ✓ Added (total: 154)
#
# Cost Set 146/200:
#   Costs: 2.50/h, 1.2378/km, parking×1.15
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=659.5, unplanned=20
#   ✓ Added (total: 155)
#
# Cost Set 147/200:
#   Costs: 14.36/h, 0.0895/km, parking×0.98
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.6km, 30.4h, parking=835.2, unplanned=20
#   ✓ Added (total: 156)
#
# Cost Set 148/200:
#   Costs: 1.15/h, 0.1947/km, parking×9.00
#   ✓ Uploaded, waiting 60s...
#   Features: 982.7km, 34.4h, parking=1925.6, unplanned=2
#   ✓ Added (total: 157)
#
# Cost Set 149/200:
#   Costs: 2.70/h, 0.2833/km, parking×1.31
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=661.7, unplanned=20
#   ✓ Added (total: 158)
#
# Cost Set 150/200:
#   Costs: 5.79/h, 1.4085/km, parking×0.26
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=862.5, unplanned=20
#   ✓ Added (total: 159)
#   💾 Saved to cost_pool.json
#
#   CHECKPOINT: 159/200 | Elapsed: 2.5h | Remaining: 0.8h
#
#
# Cost Set 151/200:
#   Costs: 16.22/h, 0.0945/km, parking×0.29
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=944.2, unplanned=20
#   ✓ Added (total: 160)
#
# Cost Set 152/200:
#   Costs: 1.29/h, 0.9053/km, parking×4.30
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=975.5, unplanned=20
#   ✓ Added (total: 161)
#
# Cost Set 153/200:
#   Costs: 1.18/h, 0.1792/km, parking×7.69
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=533.8, unplanned=20
#   ✓ Added (total: 162)
#
# Cost Set 154/200:
#   Costs: 3.85/h, 0.2555/km, parking×1.33
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=697.1, unplanned=20
#   ✓ Added (total: 163)
#
# Cost Set 155/200:
#   Costs: 1.57/h, 1.9262/km, parking×0.23
#   ✓ Uploaded, waiting 60s...
#   Features: 953.1km, 33.5h, parking=48.8, unplanned=2
#   ✓ Added (total: 164)
#
# Cost Set 156/200:
#   Costs: 5.59/h, 1.4774/km, parking×4.57
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=477.5, unplanned=20
#   ✓ Added (total: 165)
#
# Cost Set 157/200:
#   Costs: 1.22/h, 0.0301/km, parking×7.78
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=492.1, unplanned=20
#   ✓ Added (total: 166)
#
# Cost Set 158/200:
#   Costs: 5.75/h, 1.1252/km, parking×6.29
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=812.2, unplanned=20
#   ✓ Added (total: 167)
#
# Cost Set 159/200:
#   Costs: 1.99/h, 0.1751/km, parking×8.22
#   ✓ Uploaded, waiting 60s...
#   Features: 1175.6km, 37.0h, parking=1755.9, unplanned=3
#   ✓ Added (total: 168)
#
# Cost Set 160/200:
#   Costs: 11.91/h, 0.0664/km, parking×0.31
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=596.6, unplanned=20
#   ✓ Added (total: 169)
#   💾 Saved to cost_pool.json
#
#   CHECKPOINT: 169/200 | Elapsed: 2.7h | Remaining: 0.7h
#
#
# Cost Set 161/200:
#   Costs: 2.07/h, 0.2183/km, parking×1.35
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=575.9, unplanned=20
#   ✓ Added (total: 170)
#
# Cost Set 162/200:
#   Costs: 11.20/h, 1.0247/km, parking×6.68
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=713.8, unplanned=20
#   ✓ Added (total: 171)
#
# Cost Set 163/200:
#   Costs: 2.01/h, 0.1939/km, parking×0.87
#   ✓ Uploaded, waiting 60s...
#   Features: 1087.8km, 35.8h, parking=186.0, unplanned=3
#   ✓ Added (total: 172)
#
# Cost Set 164/200:
#   Costs: 1.94/h, 1.0798/km, parking×0.22
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.6km, 30.4h, parking=801.9, unplanned=20
#   ✓ Added (total: 173)
#
# Cost Set 165/200:
#   Costs: 13.67/h, 1.1173/km, parking×7.86
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=98.7, unplanned=20
#   ✓ Added (total: 174)
#
# Cost Set 166/200:
#   Costs: 1.76/h, 0.1744/km, parking×7.05
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.6km, 30.4h, parking=961.0, unplanned=20
#   ✓ Added (total: 175)
#
# Cost Set 167/200:
#   Costs: 1.84/h, 0.0510/km, parking×6.46
#   ✓ Uploaded, waiting 60s...
#   Features: 1165.6km, 36.5h, parking=1351.1, unplanned=2
#   ✓ Added (total: 176)
#
# Cost Set 168/200:
#   Costs: 1.28/h, 0.1635/km, parking×7.79
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=356.1, unplanned=20
#   ✓ Added (total: 177)
#
# Cost Set 169/200:
#   Costs: 8.05/h, 0.8562/km, parking×6.88
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=626.1, unplanned=20
#   ✓ Added (total: 178)
#
# Cost Set 170/200:
#   Costs: 16.61/h, 0.0874/km, parking×0.27
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=146.7, unplanned=20
#   ✓ Added (total: 179)
#   💾 Saved to cost_pool.json
#
#   CHECKPOINT: 179/200 | Elapsed: 2.8h | Remaining: 0.5h
#
#
# Cost Set 171/200:
#   Costs: 1.42/h, 0.1340/km, parking×5.88
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=121.5, unplanned=20
#   ✓ Added (total: 180)
#
# Cost Set 172/200:
#   Costs: 1.32/h, 0.1022/km, parking×5.93
#   ✓ Uploaded, waiting 60s...
#   Features: 1007.3km, 30.4h, parking=104.9, unplanned=20
#   ✓ Added (total: 181)
#
# Cost Set 173/200:
#   Costs: 17.55/h, 0.0564/km, parking×0.39
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=44.1, unplanned=20
#   ✓ Added (total: 182)
#
# Cost Set 174/200:
#   Costs: 2.38/h, 0.2608/km, parking×0.89
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=418.7, unplanned=20
#   ✓ Added (total: 183)
#
# Cost Set 175/200:
#   Costs: 0.81/h, 0.0906/km, parking×5.33
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=684.6, unplanned=20
#   ✓ Added (total: 184)
#
# Cost Set 176/200:
#   Costs: 11.91/h, 1.1935/km, parking×6.55
#   ✓ Uploaded, waiting 60s...
#   Features: 1131.6km, 36.2h, parking=1402.2, unplanned=2
#   ✓ Added (total: 185)
#
# Cost Set 177/200:
#   Costs: 0.96/h, 0.0611/km, parking×9.55
#   ✓ Uploaded, waiting 60s...
#   Features: 1007.3km, 30.4h, parking=282.8, unplanned=20
#   ✓ Added (total: 186)
#
# Cost Set 178/200:
#   Costs: 17.82/h, 0.0577/km, parking×0.57
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=858.5, unplanned=20
#   ✓ Added (total: 187)
#
# Cost Set 179/200:
#   Costs: 2.08/h, 0.2822/km, parking×1.38
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=582.1, unplanned=20
#   ✓ Added (total: 188)
#
# Cost Set 180/200:
#   Costs: 7.46/h, 1.2472/km, parking×4.37
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=192.9, unplanned=20
#   ✓ Added (total: 189)
#   💾 Saved to cost_pool.json
#
#   CHECKPOINT: 189/200 | Elapsed: 3.0h | Remaining: 0.3h
#
#
# Cost Set 181/200:
#   Costs: 4.87/h, 0.1752/km, parking×1.32
#   ✓ Uploaded, waiting 60s...
#   Features: 1014.5km, 34.4h, parking=275.9, unplanned=3
#   ✓ Added (total: 190)
#
# Cost Set 182/200:
#   Costs: 11.30/h, 0.0994/km, parking×0.93
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=879.4, unplanned=20
#   ✓ Added (total: 191)
#
# Cost Set 183/200:
#   Costs: 14.55/h, 0.0471/km, parking×0.22
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=789.2, unplanned=20
#   ✓ Added (total: 192)
#
# Cost Set 184/200:
#   Costs: 16.87/h, 0.0211/km, parking×0.62
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=1034.0, unplanned=20
#   ✓ Added (total: 193)
#
# Cost Set 185/200:
#   Costs: 1.18/h, 1.2362/km, parking×3.10
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=881.4, unplanned=20
#   ✓ Added (total: 194)
#
# Cost Set 186/200:
#   Costs: 1.98/h, 1.5979/km, parking×0.87
#   ✓ Uploaded, waiting 60s...
#   Features: 1030.5km, 35.1h, parking=184.2, unplanned=2
#   ✓ Added (total: 195)
#
# Cost Set 187/200:
#   Costs: 12.43/h, 0.0593/km, parking×0.21
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=335.0, unplanned=20
#   ✓ Added (total: 196)
#
# Cost Set 188/200:
#   Costs: 0.67/h, 0.1915/km, parking×4.34
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=954.5, unplanned=20
#   ✓ Added (total: 197)
#
# Cost Set 189/200:
#   Costs: 1.05/h, 1.6928/km, parking×0.35
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=1009.1, unplanned=20
#   ✓ Added (total: 198)
#
# Cost Set 190/200:
#   Costs: 11.55/h, 0.3504/km, parking×5.17
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=389.6, unplanned=20
#   ✓ Added (total: 199)
#   💾 Saved to cost_pool.json
#
#   CHECKPOINT: 199/200 | Elapsed: 3.2h | Remaining: 0.2h
#
#
# Cost Set 191/200:
#   Costs: 4.51/h, 0.2138/km, parking×1.09
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=603.0, unplanned=20
#   ✓ Added (total: 200)
#
# Cost Set 192/200:
#   Costs: 0.71/h, 0.1700/km, parking×6.59
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=950.5, unplanned=20
#   ✓ Added (total: 201)
#
# Cost Set 193/200:
#   Costs: 13.23/h, 0.0250/km, parking×0.54
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=211.6, unplanned=20
#   ✓ Added (total: 202)
#
# Cost Set 194/200:
#   Costs: 3.29/h, 1.0956/km, parking×3.87
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=1013.2, unplanned=20
#   ✓ Added (total: 203)
#
# Cost Set 195/200:
#   Costs: 11.78/h, 0.0683/km, parking×0.80
#   ✓ Uploaded, waiting 60s...
#   Features: 1007.4km, 30.4h, parking=724.5, unplanned=20
#   ✓ Added (total: 204)
#
# Cost Set 196/200:
#   Costs: 12.19/h, 0.0175/km, parking×0.85
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=709.7, unplanned=20
#   ✓ Added (total: 205)
#
# Cost Set 197/200:
#   Costs: 3.66/h, 0.1903/km, parking×1.38
#   ✓ Uploaded, waiting 60s...
#   Features: 1328.0km, 38.2h, parking=288.3, unplanned=3
#   ✓ Added (total: 206)
#
# Cost Set 198/200:
#   Costs: 14.79/h, 0.0907/km, parking×0.90
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.6km, 30.4h, parking=644.8, unplanned=20
#   ✓ Added (total: 207)
#
# Cost Set 199/200:
#   Costs: 1.85/h, 1.6925/km, parking×0.36
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=504.5, unplanned=20
#   ✓ Added (total: 208)
#
# Cost Set 200/200:
#   Costs: 1.22/h, 1.7554/km, parking×0.59
#   ✓ Uploaded, waiting 60s...
#   Features: 1005.5km, 30.4h, parking=960.9, unplanned=20
#   ✓ Added (total: 209)
#   💾 Saved to cost_pool.json
#
#   CHECKPOINT: 209/200 | Elapsed: 3.3h | Remaining: 0.0h
#
#   💾 Saved to cost_pool.json
#
# ============================================================
# PHASE 1 COMPLETE
# ============================================================
# Cost pool: 209 solutions
# Time: 3.3 hours
# Saved to: cost_pool.json
# ============================================================

# %% [markdown]
# ## 7. Analyze Cost Pool (Optional)

# %%
# Quick analysis
if len(collector.cost_pool) > 0:
    analyzer = ParetoAnalyzer(collector.cost_pool)
    top_30 = analyzer.get_top_n_solutions(n=30)
    
    print(f"Cost pool analysis:")
    print(f"  Total solutions: {len(collector.cost_pool)}")
    print(f"  Top 30 solutions: {len(top_30)}")
    print(f"  Top 30 = top {100*len(top_30)/len(collector.cost_pool):.1f}%")
    
    # Check unplanned jobs
    unplanned = [s['features']['unplanned_jobs'] for s in collector.cost_pool]
    print(f"\n  Unplanned jobs: min={min(unplanned)}, max={max(unplanned)}, avg={np.mean(unplanned):.1f}")
    if max(unplanned) > 5:
        print(f"  ⚠️  Consider using relaxed model (remove skill requirements)")
# Out:
# Cost pool analysis:
#   Total solutions: 209
#   Top 30 solutions: 30
#   Top 30 = top 14.4%
#
#   Unplanned jobs: min=2, max=20, avg=15.8
#   ⚠️  Consider using relaxed model (remove skill requirements)

# %% [markdown]
# ## 8. Phase 2: Generate Training Samples

# %%
collector.generate_training_samples(
    n_samples=N_SAMPLES,
    top_n=TOP_N,
    top_k=TOP_K
)
# Out:
# ============================================================
# PHASE 2: GENERATING TRAINING SAMPLES
# ============================================================
# Cost pool: 209 solutions
# Preferences: 400
# Top-N selection: 100
# Top-K per preference: 3
# Total samples: 1200
# ============================================================
#
# Preference 400/400
#
# ============================================================
# PHASE 2 COMPLETE
# ============================================================
# Generated: 1200 samples
# From: 400 preferences × top-3
# Saved to: training_data_20251029_205312/
#   - training_data.json
#
# Diversity: 9 unique solutions used
# Avg samples per solution: 133.3
# ============================================================

# %%
def visualize_training_data(training_data_file, cost_pool_file):
    """
    Create visualizations for training data and save to dedicated folder
    
    Creates folder: {training_data_file_stem}/
    Saves: pareto_visualization.png, usage_analysis.png
    """
    import json
    import numpy as np
    import matplotlib.pyplot as plt
    from mpl_toolkits.mplot3d import Axes3D
    from collections import Counter
    from pathlib import Path
    
    # Use the same folder as training data
    output_dir = Path(training_data_file).parent
    print(f"\n📁 Creating visualizations in: {output_dir}/")
    
    # Load data
    with open(cost_pool_file, 'r') as f:
        cost_pool = json.load(f)
    
    with open(training_data_file, 'r') as f:
        training_data = json.load(f)
    
    print(f"  Cost pool: {len(cost_pool)} solutions")
    print(f"  Training data: {len(training_data)} samples")
    
    # Extract features
    all_parking = [s['features']['avg_parking_difficulty'] for s in cost_pool]
    all_time = [s['features']['total_travel_hours'] for s in cost_pool]
    all_distance = [s['features']['total_distance_km'] for s in cost_pool]
    
    # Get pool_ids used in training
    training_pool_ids = set([s['metadata']['pool_id'] for s in training_data])
    
    # Separate into used/unused
    used_parking = [s['features']['avg_parking_difficulty'] for s in cost_pool if s['pool_id'] in training_pool_ids]
    used_time = [s['features']['total_travel_hours'] for s in cost_pool if s['pool_id'] in training_pool_ids]
    used_distance = [s['features']['total_distance_km'] for s in cost_pool if s['pool_id'] in training_pool_ids]
    
    unused_parking = [s['features']['avg_parking_difficulty'] for s in cost_pool if s['pool_id'] not in training_pool_ids]
    unused_time = [s['features']['total_travel_hours'] for s in cost_pool if s['pool_id'] not in training_pool_ids]
    unused_distance = [s['features']['total_distance_km'] for s in cost_pool if s['pool_id'] not in training_pool_ids]
    
    # Find Pareto front
    class SimpleParetoFinder:
        def dominates(self, a, b):
            better_in_one = False
            for key in ['avg_parking_difficulty', 'total_travel_hours', 'total_distance_km']:
                if a['features'][key] > b['features'][key]:
                    return False
                if a['features'][key] < b['features'][key]:
                    better_in_one = True
            return better_in_one
        
        def find_pareto_front(self, solutions):
            pareto = []
            for candidate in solutions:
                if not any(self.dominates(other, candidate) 
                          for other in solutions 
                          if other['pool_id'] != candidate['pool_id']):
                    pareto.append(candidate)
            return pareto
    
    finder = SimpleParetoFinder()
    pareto_front = finder.find_pareto_front(cost_pool)
    
    pareto_parking = [s['features']['avg_parking_difficulty'] for s in pareto_front]
    pareto_time = [s['features']['total_travel_hours'] for s in pareto_front]
    pareto_distance = [s['features']['total_distance_km'] for s in pareto_front]
    pareto_ids = [s['pool_id'] for s in pareto_front]
    
    print(f"  Pareto front: {len(pareto_front)} solutions")
    print(f"  Used in training: {len(training_pool_ids)} unique solutions")
    
    # =========================================================================
    # VISUALIZATION 1: 3D Scatter Plot + 2D Projections
    # =========================================================================
    
    fig = plt.figure(figsize=(16, 12))
    
    # Plot 1: 3D view
    ax1 = fig.add_subplot(2, 2, 1, projection='3d')
    
    # Unused solutions (gray)
    ax1.scatter(unused_parking, unused_time, unused_distance, 
               c='lightgray', s=30, alpha=0.3, label='Unused in training')
    
    # Used solutions (blue)
    ax1.scatter(used_parking, used_time, used_distance,
               c='steelblue', s=100, alpha=0.7, edgecolors='black', 
               linewidths=1, label=f'Used in training ({len(training_pool_ids)})')
    
    # Pareto front (red stars)
    ax1.scatter(pareto_parking, pareto_time, pareto_distance,
               c='red', s=300, marker='*', edgecolors='black',
               linewidths=2, label=f'Pareto front ({len(pareto_front)})', zorder=10)
    
    ax1.set_xlabel('Parking Difficulty', fontsize=10)
    ax1.set_ylabel('Travel Time (hours)', fontsize=10)
    ax1.set_zlabel('Distance (km)', fontsize=10)
    ax1.set_title('3D Feature Space: Training Data + Pareto Front', fontsize=12, fontweight='bold')
    ax1.legend(fontsize=9)
    

    
    
    for row, col, pos, x_feat, y_feat, title in projections:
        ax = fig.add_subplot(row, col, pos) 
        
        # Extract data for this projection
        unused_x = [s['features'][x_feat] for s in cost_pool if s['pool_id'] not in training_pool_ids]
        unused_y = [s['features'][y_feat] for s in cost_pool if s['pool_id'] not in training_pool_ids]
        
        used_x = [s['features'][x_feat] for s in cost_pool if s['pool_id'] in training_pool_ids]
        used_y = [s['features'][y_feat] for s in cost_pool if s['pool_id'] in training_pool_ids]
        
        pareto_x = [s['features'][x_feat] for s in pareto_front]
        pareto_y = [s['features'][y_feat] for s in pareto_front]
        
        # Plot
        ax.scatter(unused_x, unused_y, c='lightgray', s=30, alpha=0.3, label='Unused')
        ax.scatter(used_x, used_y, c='steelblue', s=100, alpha=0.7, 
                  edgecolors='black', linewidths=1, label='Used')
        ax.scatter(pareto_x, pareto_y, c='red', s=300, marker='*',
                  edgecolors='black', linewidths=2, label='Pareto', zorder=10)
        
        # Add pool_id labels for Pareto points
        for s in pareto_front:
            ax.annotate(f"ID={s['pool_id']}", 
                       (s['features'][x_feat], s['features'][y_feat]),
                       xytext=(5, 5), textcoords='offset points', 
                       fontsize=8, alpha=0.7)
        
        ax.set_xlabel(x_feat.replace('_', ' ').title(), fontsize=10)
        ax.set_ylabel(y_feat.replace('_', ' ').title(), fontsize=10)
        ax.set_title(title, fontsize=11, fontweight='bold')
        ax.legend(fontsize=8)
        ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    viz1_path = Path(output_dir) / 'pareto_visualization.png'
    plt.savefig(viz1_path, dpi=150, bbox_inches='tight')
    plt.close()
    print(f"  ✓ Saved: {viz1_path}")
    
    # =========================================================================
    # VISUALIZATION 2: Usage Analysis
    # =========================================================================
    
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    
    # Count how many times each solution is used
    pool_id_counts = Counter([s['metadata']['pool_id'] for s in training_data])
    
    # Left plot: Bar chart of usage
    ax = axes[0]
    pool_ids_sorted = sorted(pool_id_counts.keys())
    counts = [pool_id_counts[pid] for pid in pool_ids_sorted]
    colors = ['red' if pid in pareto_ids else 'steelblue' for pid in pool_ids_sorted]
    
    bars = ax.bar(range(len(pool_ids_sorted)), counts, color=colors, 
                 edgecolor='black', alpha=0.7)
    ax.set_xlabel('Pool ID', fontsize=12)
    ax.set_ylabel('Times Used in Training', fontsize=12)
    ax.set_title(f'Solution Usage Distribution\n(Red = Pareto front)', 
                fontsize=12, fontweight='bold')
    ax.set_xticks(range(len(pool_ids_sorted)))
    ax.set_xticklabels([f'{pid}' for pid in pool_ids_sorted], rotation=90, fontsize=8)
    ax.grid(True, alpha=0.3, axis='y')
    
    # Add percentage labels on top
    for i, (bar, count) in enumerate(zip(bars, counts)):
        pct = count / len(training_data) * 100
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + max(counts)*0.01,
               f'{pct:.1f}%', ha='center', va='bottom', fontsize=8)
    
    # Right plot: Pareto vs Non-Pareto usage
    ax = axes[1]
    
    pareto_usage = sum(pool_id_counts.get(pid, 0) for pid in pareto_ids)
    non_pareto_usage = len(training_data) - pareto_usage
    
    pareto_in_training = len([pid for pid in training_pool_ids if pid in pareto_ids])
    non_pareto_in_training = len(training_pool_ids) - pareto_in_training
    
    labels = [f'Pareto Front\n({pareto_in_training} solutions)', 
              f'Non-Pareto\n({non_pareto_in_training} solutions)']
    sizes = [pareto_usage, non_pareto_usage]
    colors_pie = ['red', 'steelblue']
    
    wedges, texts, autotexts = ax.pie(sizes, labels=labels, colors=colors_pie,
                                       autopct='%1.1f%%', startangle=90,
                                       textprops={'fontsize': 11, 'fontweight': 'bold'})
    ax.set_title('Training Data: Pareto vs Non-Pareto Usage', 
                fontsize=12, fontweight='bold')
    
    plt.tight_layout()
    viz2_path = Path(output_dir) / 'usage_analysis.png'
    plt.savefig(viz2_path, dpi=150, bbox_inches='tight')
    plt.close()
    print(f"  ✓ Saved: {viz2_path}")
    
    # =========================================================================
    # STATISTICS SUMMARY
    # =========================================================================
    
    stats_path = Path(output_dir) / 'statistics.txt'
    with open(stats_path, 'w') as f:
        f.write("="*60 + "\n")
        f.write("TRAINING DATA STATISTICS\n")
        f.write("="*60 + "\n\n")
        
        f.write(f"Cost Pool:\n")
        f.write(f"  Total solutions: {len(cost_pool)}\n")
        f.write(f"  Pareto front: {len(pareto_front)} ({len(pareto_front)/len(cost_pool)*100:.1f}%)\n\n")
        
        f.write(f"Training Data:\n")
        f.write(f"  Total samples: {len(training_data)}\n")
        f.write(f"  Unique solutions: {len(training_pool_ids)}\n")
        f.write(f"  Samples per solution: {len(training_data)/len(training_pool_ids):.1f}\n\n")
        
        f.write(f"Pareto Front Usage:\n")
        f.write(f"  Pareto solutions in training: {pareto_in_training}/{len(pareto_front)}\n")
        f.write(f"  Pareto samples: {pareto_usage}/{len(training_data)} ({pareto_usage/len(training_data)*100:.1f}%)\n\n")
        
        f.write(f"Top 5 most used solutions:\n")
        for pool_id, count in pool_id_counts.most_common(5):
            is_pareto = "⭐ PARETO" if pool_id in pareto_ids else ""
            f.write(f"  pool_id={pool_id}: {count} times ({count/len(training_data)*100:.1f}%) {is_pareto}\n")
        
        f.write("\n" + "="*60 + "\n")
    
    print(f"  ✓ Saved: {stats_path}")
    print(f"\n✅ All visualizations saved to: {output_dir}/\n")

print("✓ visualize_training_data function defined")
visualize_training_data(
    f'training_data_20251029_205312/training_data.json',
    'cost_pool.json'
)
# Out:
# ✓ visualize_training_data function defined
#
# 📁 Creating visualizations in: training_data_20251029_205312/
#   Cost pool: 209 solutions
#   Training data: 1200 samples
#   Pareto front: 6 solutions
#   Used in training: 9 unique solutions
#   ✓ Saved: training_data_20251029_205312/pareto_visualization.png
#   ✓ Saved: training_data_20251029_205312/usage_analysis.png
#   ✓ Saved: training_data_20251029_205312/statistics.txt
#
# ✅ All visualizations saved to: training_data_20251029_205312/

# %% [markdown]
# ## 9. View Sample

# %%
# Show first training sample
if len(collector.training_data) > 0:
    print(json.dumps(collector.training_data[0], indent=2))
# Out:
# {
#   "sample_id": 1,
#   "preferences": {
#     "parking_importance": 0.04314823087550373,
#     "time_importance": 0.28700060829194274,
#     "distance_importance": 0.6698511608325536
#   },
#   "costs": {
#     "costPerTravelHour": 1.04,
#     "costPerKm": 0.0241,
#     "parking_multiplier": 1.48
#   },
#   "features": {
#     "total_distance_km": 992.98,
#     "total_travel_hours": 30.23,
#     "total_cost": 494286.75,
#     "num_stops": 172,
#     "num_vehicles_used": 8,
#     "unplanned_jobs": 20,
#     "avg_parking_difficulty": 309.84
#   },
#   "metadata": {
#     "pool_id": 58,
#     "rank_for_preference": 1,
#     "pareto_distance": 0.03996298278396572,
#     "selection_pool_size": 30,
#     "timestamp": "2025-10-29T10:44:21.690797"
#   }
# }
