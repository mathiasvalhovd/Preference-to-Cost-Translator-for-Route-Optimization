# %% [markdown]
# # Data Collection Pipeline V3 - Cost Pool Approach
#
# This is the **most efficient approach** for collecting training data!
#
# ## How It Works:
#
# ### Phase 1: Build Cost Pool (~7.5 hours)
# 1. Generate 300 random cost sets
# 2. Optimize each once
# 3. Store all (costs, features) pairs
#
# ### Phase 2: Match Preferences (~instant)
# 1. Generate random preferences
# 2. Score all 300 solutions against preferences
# 3. Pick best match
# 4. Save (preference, best_costs, best_features)
# 5. Repeat to create 400+ training samples!
#
# ## Benefits:
# - ✅ **400+ training samples from 300 optimizations**
# - ✅ **Much faster**: ~7.5 hours (vs 20 hours for 200 samples)
# - ✅ **Better diversity**: All preferences see all costs
# - ✅ **Reusable**: Can generate more samples anytime
# - ✅ **Fallback**: Generates custom costs for poor matches

# %%
import json
import time
import requests
import numpy as np
import pandas as pd
from datetime import datetime
from pathlib import Path
import copy

print("✓ Imports successful")
# Out:
# ✓ Imports successful

# %% [markdown]
# ## Configuration
#
# **⚠️ CHANGE THESE VALUES:**

# %%
# API Configuration


# Model file (25 jobs, 8 vehicles)
MODEL_PATH = "../../test_model_mathias_fixed.json"  # ← Your model file

# Phase 1: Cost pool generation
POOL_SIZE = 200  # Number of random cost sets to generate
COST_POOL_FILE = "cost_pool.json"
POOL_CHECKPOINT_EVERY = 10  # Save every 10 cost sets

# Phase 2: Preference matching
N_PREFERENCE_SAMPLES = 400  # Number of training samples to generate
MATCH_QUALITY_THRESHOLD = 500  # If best score > this, generate custom costs
OUTPUT_FILE = "training_data_v3_pool.json"

# Optimization settings
WAIT_SECONDS = 120  # Wait time for each optimization

# Cost parameter ranges
COST_RANGES = {
    'costPerTravelHour': (0.5, 5.0),
    'costPerKm': (0.014, 0.49),
    'parking_multiplier': (0.2, 5.0)
}

print(f"Configuration:")
print(f"  Base URL: {BASE_URL}")
print(f"  Model: {MODEL_PATH}")
print(f"\nPhase 1 - Cost Pool:")
print(f"  Pool size: {POOL_SIZE}")
print(f"  Estimated time: {(POOL_SIZE * WAIT_SECONDS) / 3600:.1f} hours")
print(f"  Output: {COST_POOL_FILE}")
print(f"\nPhase 2 - Preference Matching:")
print(f"  Training samples: {N_PREFERENCE_SAMPLES}")
print(f"  Match threshold: {MATCH_QUALITY_THRESHOLD}")
print(f"  Output: {OUTPUT_FILE}")
print(f"\nTotal estimated time: ~{(POOL_SIZE * WAIT_SECONDS) / 3600:.1f} hours")
# Out:
# Configuration:
#   Base URL: https://optimizer-0.staging.zenderatms.com
#   Model: ../../test_model_mathias_fixed.json
#
# Phase 1 - Cost Pool:
#   Pool size: 200
#   Estimated time: 6.7 hours
#   Output: cost_pool.json
#
# Phase 2 - Preference Matching:
#   Training samples: 400
#   Match threshold: 500
#   Output: training_data_v3_pool.json
#
# Total estimated time: ~6.7 hours

# %%
# Run this to see what file the collector is actually using
import json

with open(MODEL_PATH, 'r') as f:
    model = json.load(f)

# Check dates
from datetime import datetime
dates = set()
for job in model['data']['jobs']:
    for stop in job['stops']:
        for tw in stop['multiTWs']:
            dt = datetime.fromisoformat(tw['openTime'])
            dates.add(dt.date())

print(f"Dates in loaded model: {sorted(dates)}")
print(f"Today: {datetime.now().date()}")
# Out:
# Dates in loaded model: [datetime.date(2025, 10, 28), datetime.date(2025, 10, 29), datetime.date(2025, 10, 30)]
# Today: 2025-10-27

# %% [markdown]
# ## Cost Pool Data Collector Class

# %%
class CostPoolDataCollector:
    """Two-phase data collector using cost pool approach"""
    
    def __init__(self, base_url, username, password, model_path, cost_ranges):
        """Initialize data collector"""
        self.base_url = base_url.rstrip('/')
        self.username = username
        self.password = password
        self.cost_ranges = cost_ranges
        
        # Initialize session
        self.session = requests.Session()
        self.session.auth = (username, password)
        self.session.headers.update({
            'Content-Type': 'application/json',
            'Accept': 'application/json'
        })
        
        # Load base model
        with open(model_path, 'r') as f:
            self.base_model = json.load(f)
        
        print(f"✓ Base model loaded")
        print(f"  Jobs: {len(self.base_model['data']['jobs'])}")
        print(f"  Vehicles: {len(self.base_model['data']['vehicles'])}")
        
        # Data storage
        self.cost_pool = []  # List of {costs, features, pool_id}
        self.training_data = []  # Final training samples
    
    def sample_random_costs(self):
        """Sample random cost parameters from valid ranges"""
        costs = {}
        for param, (min_val, max_val) in self.cost_ranges.items():
            costs[param] = np.random.uniform(min_val, max_val)
        
        # Round for cleaner values
        costs['costPerTravelHour'] = round(costs['costPerTravelHour'], 2)
        costs['costPerKm'] = round(costs['costPerKm'], 4)
        costs['parking_multiplier'] = round(costs['parking_multiplier'], 2)
        
        return costs
    
    def sample_preferences(self):
        """Sample random preference values"""
        preferences = {
            'parking_importance': np.random.uniform(0.0, 1.0),
            'time_importance': np.random.uniform(0.0, 1.0),
            'distance_importance': np.random.uniform(0.0, 1.0)
        }
        return preferences
    
    def apply_costs_to_model(self, costs):
        """Apply cost parameters to model"""
        model = copy.deepcopy(self.base_model)
        
        # Apply vehicle costs
        for vehicle in model['data']['vehicles']:
            if 'definition' in vehicle:
                vehicle['definition']['costPerTravelHour'] = costs['costPerTravelHour']
                vehicle['definition']['costPerKm'] = costs['costPerKm']
        
        # Apply parking multiplier ONLY to delivery stops
        for job in model['data']['jobs']:
            for stop in job.get('stops', []):
                # Only multiply parking cost if:
                # 1. It's a delivery stop
                # 2. Parking cost is already > 0
                if (stop.get('type') == 'SHIPMENT_DELIVERY' and 
                    'parking' in stop and 
                    'cost' in stop['parking'] and 
                    stop['parking']['cost'] > 0):
                    
                    original_cost = stop['parking']['cost']
                    stop['parking']['cost'] = original_cost * costs['parking_multiplier']
        
        return model
    
    def send_to_odl(self, model, model_id):
        """Send model to ODL API"""
        url = f"{self.base_url}/models/{model_id}"
        
        try:
            response = self.session.put(url, json=model, timeout=30)
            response.raise_for_status()
            return True
        except Exception as e:
            print(f"  ✗ Upload failed: {e}")
            return False
    
    def get_plan(self, model_id):
        """Retrieve plan from ODL API"""
        url = url = f"{self.base_url}/models/{model_id}/optimiserstate/plan"
        
        try:
            response = self.session.get(url, timeout=30)
            response.raise_for_status()
            return response.json()
        except Exception as e:
            print(f"  ✗ Get plan failed: {e}")
            return None
        
    def extract_features(self, plan):
        """Extract route features from plan"""
        if not plan or 'vehiclePlans' not in plan:
            return None
        
        features = {
            'total_distance_km': 0.0,
            'total_travel_hours': 0.0,
            'total_cost': 0.0,
            'num_stops': 0,
            'num_vehicles_used': 0,
            'unplanned_jobs': len(plan.get('unplannedJobs', [])),
            'avg_parking_difficulty': 0.0
        }
        
        total_parking_cost = 0.0
        total_stops = 0
        
        for vehicle_plan in plan['vehiclePlans']:
            stops = vehicle_plan.get('plannedStops', [])
            
            if len(stops) > 0:
                features['num_vehicles_used'] += 1
                features['num_stops'] += len(stops)
                total_stops += len(stops)
            
            # Get distance, time, and cost from timeStatistics
            time_stats = vehicle_plan.get('timeStatistics', {})
            features['total_distance_km'] += time_stats.get('travelMetres', 0) / 1000.0
            features['total_travel_hours'] += time_stats.get('travelSeconds', 0) / 3600.0
            features['total_cost'] += time_stats.get('cost', 0)
            
            # Get parking cost from optimiserCostBreakdown (UPPERCASE!)
            breakdown = time_stats.get('optimiserCostBreakdown', {})
            total_parking_cost += breakdown.get('PARKING_COST', 0.0)  # ← UPPERCASE!
        
        # Calculate average parking difficulty
        if total_stops > 0:
            features['avg_parking_difficulty'] = total_parking_cost / total_stops
        
        # Round for cleaner values
        features['total_distance_km'] = round(features['total_distance_km'], 2)
        features['total_travel_hours'] = round(features['total_travel_hours'], 2)
        features['total_cost'] = round(features['total_cost'], 2)
        features['avg_parking_difficulty'] = round(features['avg_parking_difficulty'], 2)
        
        return features
    
    def score_solution(self, preferences, features):
        """
        Score how well a solution matches preferences.
        Lower score = better match
        """
        if features is None:
            return float('inf')
        
        score = 0.0
        
        # Parking importance
        score += preferences['parking_importance'] * features['avg_parking_difficulty']
        
        # Time importance (scaled up for balance)
        score += preferences['time_importance'] * features['total_travel_hours'] * 10
        
        # Distance importance (scaled down for balance)
        score += preferences['distance_importance'] * features['total_distance_km'] * 0.1
        
        # Penalty for unplanned jobs
        score += features['unplanned_jobs'] * 1000
        
        return score
    
    # ============================================================
    # PHASE 1: BUILD COST POOL
    # ============================================================
    
    def build_cost_pool(self, pool_size, wait_seconds, checkpoint_every, pool_file):
        """
        Phase 1: Generate pool of cost sets with their optimized solutions
        """
        print(f"\n{'='*60}")
        print(f"PHASE 1: BUILDING COST POOL")
        print(f"{'='*60}")
        print(f"Target pool size: {pool_size}")
        print(f"Estimated time: {(pool_size * wait_seconds) / 3600:.1f} hours")
        print(f"Output: {pool_file}")
        print(f"{'='*60}\n")
        
        start_time = time.time()
        
        try:
            for i in range(1, pool_size + 1):
                print(f"\nCost Set {i}/{pool_size}:")
                
                try:
                    # Generate random costs
                    costs = self.sample_random_costs()
                    print(f"  Costs: hourly={costs['costPerTravelHour']:.2f}, "
                          f"km={costs['costPerKm']:.4f}, parking_mult={costs['parking_multiplier']:.2f}")
                    
                    # Apply to model and send to API
                    model = self.apply_costs_to_model(costs)
                    model_id = f"cost_pool_{i}"
                    
                    if not self.send_to_odl(model, model_id):
                        print(f"  ✗ Failed to send model, skipping...")
                        continue
                    
                    print(f"  ✓ Model uploaded, waiting {wait_seconds}s for optimization...")
                    time.sleep(wait_seconds)
                    
                    # Get results
                    plan = self.get_plan(model_id)
                    features = self.extract_features(plan)
                    
                    if features is None:
                        print(f"  ✗ Failed to extract features, skipping...")
                        continue
                    
                    print(f"  Features: dist={features['total_distance_km']:.1f}km, "
                          f"time={features['total_travel_hours']:.1f}h, "
                          f"parking={features['avg_parking_difficulty']:.1f}")
                    
                    # Add to pool
                    self.cost_pool.append({
                        'pool_id': i,
                        'costs': costs,
                        'features': features,
                        'timestamp': datetime.now().isoformat()
                    })
                    
                    print(f"  ✓ Added to pool (total: {len(self.cost_pool)})")
                    
                    # Checkpoint
                    if i % checkpoint_every == 0:
                        self.save_cost_pool(pool_file)
                        elapsed = time.time() - start_time
                        avg_time = elapsed / len(self.cost_pool)
                        remaining = (pool_size - i) * avg_time
                        
                        print(f"\n  {'='*56}")
                        print(f"  CHECKPOINT: {len(self.cost_pool)}/{pool_size} cost sets in pool")
                        print(f"  Elapsed: {elapsed/3600:.1f} hours")
                        print(f"  Remaining: {remaining/3600:.1f} hours")
                        print(f"  {'='*56}\n")
                
                except Exception as e:
                    print(f"  ✗ Error: {e}")
                    continue
        
        except KeyboardInterrupt:
            print(f"\n\nInterrupted by user!")
            print(f"Cost pool has {len(self.cost_pool)} entries so far")
        
        # Final save
        self.save_cost_pool(pool_file)
        
        elapsed = time.time() - start_time
        print(f"\n{'='*60}")
        print(f"PHASE 1 COMPLETE")
        print(f"{'='*60}")
        print(f"Cost pool size: {len(self.cost_pool)}")
        print(f"Total time: {elapsed/3600:.1f} hours")
        if len(self.cost_pool) > 0:
            print(f"Average time per cost set: {elapsed/len(self.cost_pool):.1f} seconds")
        print(f"Data saved to: {pool_file}")
        print(f"{'='*60}\n")
    
    def save_cost_pool(self, pool_file):
        """Save cost pool to file"""
        with open(pool_file, 'w') as f:
            json.dump(self.cost_pool, f, indent=2)
        print(f"  💾 Saved {len(self.cost_pool)} cost sets to {pool_file}")
    
    def load_cost_pool(self, pool_file):
        """Load cost pool from file"""
        try:
            with open(pool_file, 'r') as f:
                self.cost_pool = json.load(f)
            print(f"✓ Loaded cost pool with {len(self.cost_pool)} entries from {pool_file}")
            return True
        except FileNotFoundError:
            print(f"✗ Cost pool file not found: {pool_file}")
            return False
    
    # ============================================================
    # PHASE 2: MATCH PREFERENCES TO POOL
    # ============================================================
    
    def find_best_match_in_pool(self, preferences):
        """
        Find the best matching cost set from the pool for given preferences
        """
        if len(self.cost_pool) == 0:
            return None
        
        best_match = None
        best_score = float('inf')
        
        for entry in self.cost_pool:
            score = self.score_solution(preferences, entry['features'])
            if score < best_score:
                best_score = score
                best_match = entry
        
        return {
            'costs': best_match['costs'],
            'features': best_match['features'],
            'score': best_score,
            'pool_id': best_match['pool_id']
        }
    
    def generate_custom_costs_for_preference(self, preferences, wait_seconds):
        """
        Fallback: Generate and optimize 5 custom costs for a preference with poor matches
        """
        print(f"    Generating 5 custom costs (poor match in pool)...")
        
        candidates = []
        
        for i in range(5):
            costs = self.sample_random_costs()
            model = self.apply_costs_to_model(costs)
            model_id = f"custom_costs_{datetime.now().timestamp()}_{i}"
            
            if not self.send_to_odl(model, model_id):
                continue
            
            time.sleep(wait_seconds)
            plan = self.get_plan(model_id)
            features = self.extract_features(plan)
            
            if features is None:
                continue
            
            score = self.score_solution(preferences, features)
            candidates.append({
                'costs': costs,
                'features': features,
                'score': score
            })
        
        if len(candidates) == 0:
            return None
        
        return min(candidates, key=lambda x: x['score'])
    
    def generate_training_samples(self, n_samples, match_threshold, wait_seconds, output_file):
        """
        Phase 2: Generate training samples by matching preferences to cost pool
        """
        if len(self.cost_pool) == 0:
            print("✗ Cost pool is empty! Run Phase 1 first.")
            return
        
        print(f"\n{'='*60}")
        print(f"PHASE 2: GENERATING TRAINING SAMPLES")
        print(f"{'='*60}")
        print(f"Cost pool size: {len(self.cost_pool)}")
        print(f"Target samples: {n_samples}")
        print(f"Match threshold: {match_threshold}")
        print(f"Output: {output_file}")
        print(f"{'='*60}\n")
        
        custom_costs_generated = 0
        
        for i in range(1, n_samples + 1):
            print(f"\nSample {i}/{n_samples}:")
            
            # Sample preferences
            preferences = self.sample_preferences()
            print(f"  Preferences: parking={preferences['parking_importance']:.2f}, "
                  f"time={preferences['time_importance']:.2f}, "
                  f"distance={preferences['distance_importance']:.2f}")
            
            # Find best match in pool
            match = self.find_best_match_in_pool(preferences)
            
            if match is None:
                print(f"  ✗ No match found, skipping...")
                continue
            
            print(f"  Best match: pool_id={match['pool_id']}, score={match['score']:.2f}")
            
            # Check match quality
            if match['score'] > match_threshold:
                print(f"  ⚠️  Score too high (>{match_threshold}), generating custom costs...")
                custom_match = self.generate_custom_costs_for_preference(preferences, wait_seconds)
                
                if custom_match is not None and custom_match['score'] < match['score']:
                    match = custom_match
                    match['pool_id'] = 'custom'
                    custom_costs_generated += 1
                    print(f"    ✓ Custom costs better: score={match['score']:.2f}")
            
            # Create training sample
            sample = {
                'sample_num': i,
                'preferences': preferences,
                'costs': match['costs'],
                'features': match['features'],
                'score': match['score'],
                'pool_id': match['pool_id'],
                'timestamp': datetime.now().isoformat()
            }
            
            self.training_data.append(sample)
            print(f"  ✓ Sample added (total: {len(self.training_data)})")
            
            # Save periodically
            if i % 50 == 0:
                self.save_training_data(output_file)
                print(f"\n  💾 Checkpoint: {len(self.training_data)} samples saved\n")
        
        # Final save
        self.save_training_data(output_file)
        
        print(f"\n{'='*60}")
        print(f"PHASE 2 COMPLETE")
        print(f"{'='*60}")
        print(f"Training samples generated: {len(self.training_data)}")
        print(f"Custom costs generated: {custom_costs_generated}")
        print(f"Pool reuse rate: {(1 - custom_costs_generated/n_samples)*100:.1f}%")
        print(f"Data saved to: {output_file}")
        print(f"{'='*60}\n")
    
    def save_training_data(self, output_file):
        """Save training data to file"""
        with open(output_file, 'w') as f:
            json.dump(self.training_data, f, indent=2)
        print(f"💾 Saved {len(self.training_data)} training samples to {output_file}")

# %% [markdown]
# ## Initialize Collector

# %%
# Validate configuration
if USERNAME == "your-username" or PASSWORD == "your-password":
    print("❌ ERROR: Please set your USERNAME and PASSWORD in the configuration cell above!")
else:
    # Initialize collector
    collector = CostPoolDataCollector(
        base_url=BASE_URL,
        username=USERNAME,
        password=PASSWORD,
        model_path=MODEL_PATH,
        cost_ranges=COST_RANGES
    )
    print("\n✓ Cost pool collector initialized and ready!")
# Out:
# ✓ Base model loaded
#   Jobs: 106
#   Vehicles: 26
#
# ✓ Cost pool collector initialized and ready!

# %%
# TEST
# Run this diagnostic cell to find the real problem
import json
from datetime import datetime
import time

# Generate test costs
test_costs = collector.sample_random_costs()
print(f"Test costs: {test_costs}\n")

# Apply to model
test_model = collector.apply_costs_to_model(test_costs)

# Send it
model_id = "diagnostic_test"
print(f"Sending to API...")
success = collector.send_to_odl(test_model, model_id)

if not success:
    print("✗ Upload failed!")
else:
    print(f"✓ Upload successful")
    print(f"\nWaiting 90 seconds for optimization...")
    time.sleep(90)
    
    print(f"Getting plan...")
    plan = collector.get_plan(model_id)
    
    if not plan:
        print("✗ No plan returned - API issue?")
    else:
        print(f"✓ Got plan back!\n")
        
        # Key diagnostics
        unplanned = plan.get('unplannedJobs', [])
        vehicle_plans = plan.get('vehiclePlans', [])
        
        print(f"Summary:")
        print(f"  Total jobs in model: {len(test_model['data']['jobs'])}")
        print(f"  Unplanned jobs: {len(unplanned)}")
        print(f"  Vehicle plans: {len(vehicle_plans)}")
        
        # Check vehicles
        total_stops = 0
        for vp in vehicle_plans:
            stops = vp.get('plannedStops', [])
            total_stops += len(stops)
            if stops:
                print(f"  Vehicle {vp.get('vehicleId')}: {len(stops)} stops")
        
        print(f"  Total planned stops: {total_stops}")
        
        if len(unplanned) > 0:
            print(f"\n⚠️ PROBLEM: {len(unplanned)} jobs are unplanned!")
            print(f"\nUnplanned job reasons:")
            for uj in unplanned[:5]:  # Show first 5
                print(f"  Job {uj.get('jobId')}: {uj.get('reason', 'No reason given')}")
        
        if total_stops == 0:
            print(f"\n✗ MAJOR PROBLEM: No stops planned at all!")
            print(f"All jobs rejected by optimizer")
        
        # Extract features
        features = collector.extract_features(plan)
        print(f"\nExtracted features:")
        print(f"  {features}")
        
        if features and features['total_distance_km'] == 0:
            print(f"\n✗ This is why you're getting zeros!")
# Out:
# Test costs: {'costPerTravelHour': 3.73, 'costPerKm': 0.267, 'parking_multiplier': 0.38}
#
# Sending to API...
# ✓ Upload successful
#
# Waiting 90 seconds for optimization...
# Getting plan...
# ✓ Got plan back!
#
# Summary:
#   Total jobs in model: 106
#   Unplanned jobs: 20
#   Vehicle plans: 26
#   Vehicle 758524: 18 stops
#   Vehicle 758525: 26 stops
#   Vehicle 758526: 4 stops
#   Vehicle 759409: 20 stops
#   Vehicle 759410: 20 stops
#   Vehicle 759411: 18 stops
#   Vehicle 760317: 30 stops
#   Vehicle 760318: 36 stops
#   Total planned stops: 172
#
# ⚠️ PROBLEM: 20 jobs are unplanned!
#
# Unplanned job reasons:
#   Job None: No reason given
#   Job None: No reason given
#   Job None: No reason given
#   Job None: No reason given
#   Job None: No reason given
#
# Extracted features:
#   {'total_distance_km': 1005.55, 'total_travel_hours': 30.36, 'total_cost': 443406.61, 'num_stops': 172, 'num_vehicles_used': 8, 'unplanned_jobs': 20, 'avg_parking_difficulty': 79.8}

# %%
# Test with very different costs and longer wait
import time

test_cases = [
    {'costPerTravelHour': 0.5, 'costPerKm': 0.01, 'parking_multiplier': 0.2},  # Minimize everything
    {'costPerTravelHour': 5.0, 'costPerKm': 0.5, 'parking_multiplier': 5.0},   # Maximize everything
]

for i, costs in enumerate(test_cases):
    print(f"\n{'='*60}")
    print(f"Test {i+1}: {costs}")
    
    model = collector.apply_costs_to_model(costs)
    model_id = f"extreme_test_{i}_{datetime.now().timestamp()}"  # Very unique ID
    
    collector.send_to_odl(model, model_id)
    print(f"Waiting 120 seconds...")
    time.sleep(120)
    
    plan = collector.get_plan(model_id)
    features = collector.extract_features(plan)
    
    print(f"Features: {features}")
# Out:
# ============================================================
# Test 1: {'costPerTravelHour': 0.5, 'costPerKm': 0.01, 'parking_multiplier': 0.2}
# Waiting 120 seconds...
# Features: {'total_distance_km': 146.8, 'total_travel_hours': 4.3, 'total_cost': 807.68, 'num_stops': 18, 'num_vehicles_used': 3, 'unplanned_jobs': 16, 'avg_parking_difficulty': 0.0}
#
# ============================================================
# Test 2: {'costPerTravelHour': 5.0, 'costPerKm': 0.5, 'parking_multiplier': 5.0}
# Waiting 120 seconds...
# Features: {'total_distance_km': 145.94, 'total_travel_hours': 4.32, 'total_cost': 20141.64, 'num_stops': 18, 'num_vehicles_used': 3, 'unplanned_jobs': 16, 'avg_parking_difficulty': 0.0}

# %% [markdown]
# ## Phase 1: Build Cost Pool
#
# This will take ~7.5 hours to generate 300 cost sets.
#
# **Run this cell once** - the pool will be saved and can be reused!

# %%
# Build cost pool (run once)
collector.build_cost_pool(
    pool_size=POOL_SIZE,
    wait_seconds=WAIT_SECONDS,
    checkpoint_every=POOL_CHECKPOINT_EVERY,
    pool_file=COST_POOL_FILE
)
# Out:
# ============================================================
# PHASE 1: BUILDING COST POOL
# ============================================================
# Target pool size: 200
# Estimated time: 6.7 hours
# Output: cost_pool.json
# ============================================================
#
#
# Cost Set 1/200:
#   Costs: hourly=3.22, km=0.0391, parking_mult=4.78
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1025.2km, time=30.6h, parking=1000.7
#   ✓ Added to pool (total: 1)
#
# Cost Set 2/200:
#   Costs: hourly=1.50, km=0.3131, parking_mult=3.93
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1007.8km, time=30.4h, parking=822.7
#   ✓ Added to pool (total: 2)
#
# Cost Set 3/200:
#   Costs: hourly=1.00, km=0.2946, parking_mult=2.69
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1001.5km, time=30.4h, parking=563.1
#   ✓ Added to pool (total: 3)
#
# Cost Set 4/200:
#   Costs: hourly=1.23, km=0.3214, parking_mult=0.42
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1001.3km, time=30.4h, parking=88.0
#   ✓ Added to pool (total: 4)
#
# Cost Set 5/200:
#   Costs: hourly=2.96, km=0.1044, parking_mult=3.81
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=999.9km, time=30.4h, parking=797.6
#   ✓ Added to pool (total: 5)
#
# Cost Set 6/200:
#   Costs: hourly=1.58, km=0.3423, parking_mult=1.06
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=999.9km, time=30.4h, parking=222.0
#   ✓ Added to pool (total: 6)
#
# Cost Set 7/200:
#   Costs: hourly=1.09, km=0.2443, parking_mult=1.12
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1029.7km, time=30.7h, parking=234.5
#   ✓ Added to pool (total: 7)
#
# Cost Set 8/200:
#   Costs: hourly=4.41, km=0.2262, parking_mult=4.67
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1007.8km, time=30.4h, parking=977.8
#   ✓ Added to pool (total: 8)
#
# Cost Set 9/200:
#   Costs: hourly=0.94, km=0.4754, parking_mult=3.20
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1007.9km, time=30.4h, parking=669.8
#   ✓ Added to pool (total: 9)
#
# Cost Set 10/200:
#   Costs: hourly=2.75, km=0.4188, parking_mult=4.05
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1007.0km, time=30.4h, parking=847.9
#   ✓ Added to pool (total: 10)
#   💾 Saved 10 cost sets to cost_pool.json
#
#   ========================================================
#   CHECKPOINT: 10/200 cost sets in pool
#   Elapsed: 0.3 hours
#   Remaining: 6.4 hours
#   ========================================================
#
#
# Cost Set 11/200:
#   Costs: hourly=2.98, km=0.4234, parking_mult=2.72
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1001.4km, time=30.4h, parking=569.5
#   ✓ Added to pool (total: 11)
#
# Cost Set 12/200:
#   Costs: hourly=2.60, km=0.1110, parking_mult=2.29
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1010.9km, time=30.5h, parking=479.5
#   ✓ Added to pool (total: 12)
#
# Cost Set 13/200:
#   Costs: hourly=1.91, km=0.3833, parking_mult=4.40
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1007.8km, time=30.4h, parking=921.1
#   ✓ Added to pool (total: 13)
#
# Cost Set 14/200:
#   Costs: hourly=2.68, km=0.3475, parking_mult=3.00
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1024.0km, time=30.6h, parking=628.1
#   ✓ Added to pool (total: 14)
#
# Cost Set 15/200:
#   Costs: hourly=4.48, km=0.2445, parking_mult=2.67
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1008.1km, time=30.4h, parking=559.1
#   ✓ Added to pool (total: 15)
#
# Cost Set 16/200:
#   Costs: hourly=3.82, km=0.1525, parking_mult=3.53
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1014.5km, time=30.6h, parking=739.1
#   ✓ Added to pool (total: 16)
#
# Cost Set 17/200:
#   Costs: hourly=3.47, km=0.4460, parking_mult=4.55
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1015.8km, time=30.5h, parking=952.6
#   ✓ Added to pool (total: 17)
#
# Cost Set 18/200:
#   Costs: hourly=2.84, km=0.3262, parking_mult=4.63
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1007.0km, time=30.4h, parking=969.3
#   ✓ Added to pool (total: 18)
#
# Cost Set 19/200:
#   Costs: hourly=1.65, km=0.2405, parking_mult=2.17
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1007.4km, time=30.5h, parking=454.3
#   ✓ Added to pool (total: 19)
#
# Cost Set 20/200:
#   Costs: hourly=2.77, km=0.2888, parking_mult=4.65
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1012.2km, time=30.5h, parking=973.5
#   ✓ Added to pool (total: 20)
#   💾 Saved 20 cost sets to cost_pool.json
#
#   ========================================================
#   CHECKPOINT: 20/200 cost sets in pool
#   Elapsed: 0.7 hours
#   Remaining: 6.0 hours
#   ========================================================
#
#
# Cost Set 21/200:
#   Costs: hourly=4.70, km=0.1761, parking_mult=4.40
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1024.0km, time=30.6h, parking=921.3
#   ✓ Added to pool (total: 21)
#
# Cost Set 22/200:
#   Costs: hourly=4.56, km=0.3595, parking_mult=1.58
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1000.0km, time=30.4h, parking=331.0
#   ✓ Added to pool (total: 22)
#
# Cost Set 23/200:
#   Costs: hourly=4.14, km=0.4731, parking_mult=0.98
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=999.9km, time=30.4h, parking=205.4
#   ✓ Added to pool (total: 23)
#
# Cost Set 24/200:
#   Costs: hourly=0.71, km=0.0322, parking_mult=3.47
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1012.9km, time=30.7h, parking=726.3
#   ✓ Added to pool (total: 24)
#
# Cost Set 25/200:
#   Costs: hourly=2.86, km=0.1153, parking_mult=0.26
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1011.9km, time=30.5h, parking=54.6
#   ✓ Added to pool (total: 25)
#
# Cost Set 26/200:
#   Costs: hourly=3.88, km=0.2234, parking_mult=3.48
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1024.0km, time=30.6h, parking=728.6
#   ✓ Added to pool (total: 26)
#
# Cost Set 27/200:
#   Costs: hourly=1.17, km=0.2995, parking_mult=1.10
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1099.0km, time=31.5h, parking=230.3
#   ✓ Added to pool (total: 27)
#
# Cost Set 28/200:
#   Costs: hourly=1.94, km=0.1956, parking_mult=4.17
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1013.8km, time=30.5h, parking=872.9
#   ✓ Added to pool (total: 28)
#
# Cost Set 29/200:
#   Costs: hourly=0.54, km=0.4836, parking_mult=0.65
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1014.8km, time=30.5h, parking=136.1
#   ✓ Added to pool (total: 29)
#
# Cost Set 30/200:
#   Costs: hourly=2.37, km=0.4240, parking_mult=2.56
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1038.5km, time=30.8h, parking=536.0
#   ✓ Added to pool (total: 30)
#   💾 Saved 30 cost sets to cost_pool.json
#
#   ========================================================
#   CHECKPOINT: 30/200 cost sets in pool
#   Elapsed: 1.0 hours
#   Remaining: 5.7 hours
#   ========================================================
#
#
# Cost Set 31/200:
#   Costs: hourly=4.25, km=0.0620, parking_mult=0.55
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1014.7km, time=30.7h, parking=115.4
#   ✓ Added to pool (total: 31)
#
# Cost Set 32/200:
#   Costs: hourly=3.64, km=0.3782, parking_mult=3.95
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1007.3km, time=30.4h, parking=827.0
#   ✓ Added to pool (total: 32)
#
# Cost Set 33/200:
#   Costs: hourly=1.34, km=0.0660, parking_mult=2.50
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1024.7km, time=30.6h, parking=523.4
#   ✓ Added to pool (total: 33)
#
# Cost Set 34/200:
#   Costs: hourly=0.75, km=0.3281, parking_mult=4.55
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1046.7km, time=30.9h, parking=952.4
#   ✓ Added to pool (total: 34)
#
# Cost Set 35/200:
#   Costs: hourly=3.14, km=0.1870, parking_mult=0.45
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1041.6km, time=30.9h, parking=94.4
#   ✓ Added to pool (total: 35)
#
# Cost Set 36/200:
#   Costs: hourly=1.16, km=0.0863, parking_mult=4.97
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1016.6km, time=30.6h, parking=1040.3
#   ✓ Added to pool (total: 36)
#
# Cost Set 37/200:
#   Costs: hourly=3.92, km=0.3718, parking_mult=4.04
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1008.9km, time=30.4h, parking=845.9
#   ✓ Added to pool (total: 37)
#
# Cost Set 38/200:
#   Costs: hourly=2.76, km=0.2515, parking_mult=3.29
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=996.4km, time=30.3h, parking=688.8
#   ✓ Added to pool (total: 38)
#
# Cost Set 39/200:
#   Costs: hourly=3.74, km=0.3666, parking_mult=2.30
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1011.3km, time=30.4h, parking=481.7
#   ✓ Added to pool (total: 39)
#
# Cost Set 40/200:
#   Costs: hourly=4.13, km=0.4018, parking_mult=1.55
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1007.9km, time=30.4h, parking=324.7
#   ✓ Added to pool (total: 40)
#   💾 Saved 40 cost sets to cost_pool.json
#
#   ========================================================
#   CHECKPOINT: 40/200 cost sets in pool
#   Elapsed: 1.3 hours
#   Remaining: 5.4 hours
#   ========================================================
#
#
# Cost Set 41/200:
#   Costs: hourly=3.21, km=0.4844, parking_mult=2.77
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1010.8km, time=30.4h, parking=580.0
#   ✓ Added to pool (total: 41)
#
# Cost Set 42/200:
#   Costs: hourly=4.04, km=0.3367, parking_mult=4.88
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=999.9km, time=30.4h, parking=1021.7
#   ✓ Added to pool (total: 42)
#
# Cost Set 43/200:
#   Costs: hourly=1.38, km=0.3231, parking_mult=3.72
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1013.5km, time=30.6h, parking=778.7
#   ✓ Added to pool (total: 43)
#
# Cost Set 44/200:
#   Costs: hourly=4.92, km=0.0387, parking_mult=1.04
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1013.3km, time=30.5h, parking=218.0
#   ✓ Added to pool (total: 44)
#
# Cost Set 45/200:
#   Costs: hourly=1.58, km=0.2322, parking_mult=0.46
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1018.5km, time=30.6h, parking=96.4
#   ✓ Added to pool (total: 45)
#
# Cost Set 46/200:
#   Costs: hourly=1.82, km=0.4464, parking_mult=1.00
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1027.2km, time=31.0h, parking=209.4
#   ✓ Added to pool (total: 46)
#
# Cost Set 47/200:
#   Costs: hourly=3.77, km=0.1089, parking_mult=1.53
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1046.2km, time=30.9h, parking=320.5
#   ✓ Added to pool (total: 47)
#
# Cost Set 48/200:
#   Costs: hourly=4.95, km=0.1346, parking_mult=1.18
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1013.5km, time=30.4h, parking=247.3
#   ✓ Added to pool (total: 48)
#
# Cost Set 49/200:
#   Costs: hourly=2.47, km=0.3743, parking_mult=2.62
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1019.4km, time=30.5h, parking=548.5
#   ✓ Added to pool (total: 49)
#
# Cost Set 50/200:
#   Costs: hourly=0.64, km=0.0563, parking_mult=0.90
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1015.6km, time=30.5h, parking=188.4
#   ✓ Added to pool (total: 50)
#   💾 Saved 50 cost sets to cost_pool.json
#
#   ========================================================
#   CHECKPOINT: 50/200 cost sets in pool
#   Elapsed: 1.7 hours
#   Remaining: 5.0 hours
#   ========================================================
#
#
# Cost Set 51/200:
#   Costs: hourly=2.43, km=0.3528, parking_mult=0.99
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1005.7km, time=30.4h, parking=207.4
#   ✓ Added to pool (total: 51)
#
# Cost Set 52/200:
#   Costs: hourly=1.05, km=0.2419, parking_mult=4.66
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1007.0km, time=30.6h, parking=975.4
#   ✓ Added to pool (total: 52)
#
# Cost Set 53/200:
#   Costs: hourly=3.46, km=0.4438, parking_mult=1.79
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1021.6km, time=30.7h, parking=374.9
#   ✓ Added to pool (total: 53)
#
# Cost Set 54/200:
#   Costs: hourly=3.80, km=0.0846, parking_mult=2.10
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1014.6km, time=30.5h, parking=439.8
#   ✓ Added to pool (total: 54)
#
# Cost Set 55/200:
#   Costs: hourly=3.19, km=0.1574, parking_mult=0.24
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1026.7km, time=30.6h, parking=50.5
#   ✓ Added to pool (total: 55)
#
# Cost Set 56/200:
#   Costs: hourly=1.31, km=0.2331, parking_mult=1.62
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1032.8km, time=30.7h, parking=339.2
#   ✓ Added to pool (total: 56)
#
# Cost Set 57/200:
#   Costs: hourly=4.19, km=0.3574, parking_mult=0.26
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1008.7km, time=30.4h, parking=54.7
#   ✓ Added to pool (total: 57)
#
# Cost Set 58/200:
#   Costs: hourly=1.04, km=0.0241, parking_mult=1.48
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=993.0km, time=30.2h, parking=309.8
#   ✓ Added to pool (total: 58)
#
# Cost Set 59/200:
#   Costs: hourly=2.52, km=0.2846, parking_mult=2.84
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1013.5km, time=30.6h, parking=594.6
#   ✓ Added to pool (total: 59)
#
# Cost Set 60/200:
#   Costs: hourly=2.20, km=0.0694, parking_mult=3.99
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1012.2km, time=30.5h, parking=835.3
#   ✓ Added to pool (total: 60)
#   💾 Saved 60 cost sets to cost_pool.json
#
#   ========================================================
#   CHECKPOINT: 60/200 cost sets in pool
#   Elapsed: 2.0 hours
#   Remaining: 4.7 hours
#   ========================================================
#
#
# Cost Set 61/200:
#   Costs: hourly=3.16, km=0.3612, parking_mult=0.28
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1027.0km, time=30.8h, parking=58.8
#   ✓ Added to pool (total: 61)
#
# Cost Set 62/200:
#   Costs: hourly=4.73, km=0.2514, parking_mult=4.58
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1010.5km, time=30.5h, parking=958.9
#   ✓ Added to pool (total: 62)
#
# Cost Set 63/200:
#   Costs: hourly=1.35, km=0.1592, parking_mult=3.53
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1024.1km, time=30.8h, parking=738.9
#   ✓ Added to pool (total: 63)
#
# Cost Set 64/200:
#   Costs: hourly=2.50, km=0.2946, parking_mult=3.27
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1011.7km, time=30.5h, parking=684.6
#   ✓ Added to pool (total: 64)
#
# Cost Set 65/200:
#   Costs: hourly=0.90, km=0.2224, parking_mult=0.86
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1045.6km, time=31.3h, parking=180.1
#   ✓ Added to pool (total: 65)
#
# Cost Set 66/200:
#   Costs: hourly=1.31, km=0.3861, parking_mult=0.90
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1049.2km, time=31.2h, parking=188.5
#   ✓ Added to pool (total: 66)
#
# Cost Set 67/200:
#   Costs: hourly=3.13, km=0.4087, parking_mult=2.30
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1024.3km, time=30.7h, parking=481.6
#   ✓ Added to pool (total: 67)
#
# Cost Set 68/200:
#   Costs: hourly=3.52, km=0.0449, parking_mult=1.87
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1043.5km, time=31.1h, parking=391.6
#   ✓ Added to pool (total: 68)
#
# Cost Set 69/200:
#   Costs: hourly=2.40, km=0.3818, parking_mult=0.24
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1017.6km, time=30.5h, parking=50.4
#   ✓ Added to pool (total: 69)
#
# Cost Set 70/200:
#   Costs: hourly=3.09, km=0.1725, parking_mult=0.84
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1157.9km, time=32.5h, parking=176.0
#   ✓ Added to pool (total: 70)
#   💾 Saved 70 cost sets to cost_pool.json
#
#   ========================================================
#   CHECKPOINT: 70/200 cost sets in pool
#   Elapsed: 2.3 hours
#   Remaining: 4.4 hours
#   ========================================================
#
#
# Cost Set 71/200:
#   Costs: hourly=4.69, km=0.3136, parking_mult=1.98
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1018.3km, time=30.6h, parking=414.8
#   ✓ Added to pool (total: 71)
#
# Cost Set 72/200:
#   Costs: hourly=0.65, km=0.1468, parking_mult=0.92
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1005.0km, time=30.5h, parking=192.6
#   ✓ Added to pool (total: 72)
#
# Cost Set 73/200:
#   Costs: hourly=3.13, km=0.0205, parking_mult=3.82
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1069.8km, time=31.3h, parking=799.8
#   ✓ Added to pool (total: 73)
#
# Cost Set 74/200:
#   Costs: hourly=1.61, km=0.1099, parking_mult=4.85
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1013.0km, time=30.8h, parking=1015.2
#   ✓ Added to pool (total: 74)
#
# Cost Set 75/200:
#   Costs: hourly=3.74, km=0.2806, parking_mult=4.58
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1021.2km, time=30.6h, parking=958.9
#   ✓ Added to pool (total: 75)
#
# Cost Set 76/200:
#   Costs: hourly=2.91, km=0.1568, parking_mult=3.67
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1023.3km, time=30.7h, parking=768.3
#   ✓ Added to pool (total: 76)
#
# Cost Set 77/200:
#   Costs: hourly=3.60, km=0.2289, parking_mult=2.70
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1022.2km, time=30.9h, parking=565.4
#   ✓ Added to pool (total: 77)
#
# Cost Set 78/200:
#   Costs: hourly=1.21, km=0.1325, parking_mult=1.01
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1016.0km, time=30.7h, parking=211.5
#   ✓ Added to pool (total: 78)
#
# Cost Set 79/200:
#   Costs: hourly=2.85, km=0.0888, parking_mult=0.70
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1037.1km, time=30.9h, parking=146.7
#   ✓ Added to pool (total: 79)
#
# Cost Set 80/200:
#   Costs: hourly=0.78, km=0.3338, parking_mult=0.83
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1013.2km, time=30.7h, parking=173.8
#   ✓ Added to pool (total: 80)
#   💾 Saved 80 cost sets to cost_pool.json
#
#   ========================================================
#   CHECKPOINT: 80/200 cost sets in pool
#   Elapsed: 2.7 hours
#   Remaining: 4.0 hours
#   ========================================================
#
#
# Cost Set 81/200:
#   Costs: hourly=4.76, km=0.0988, parking_mult=3.88
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1034.4km, time=30.9h, parking=812.4
#   ✓ Added to pool (total: 81)
#
# Cost Set 82/200:
#   Costs: hourly=2.04, km=0.0888, parking_mult=4.85
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1023.5km, time=30.7h, parking=1015.3
#   ✓ Added to pool (total: 82)
#
# Cost Set 83/200:
#   Costs: hourly=4.58, km=0.4827, parking_mult=2.28
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1012.8km, time=30.6h, parking=477.5
#   ✓ Added to pool (total: 83)
#
# Cost Set 84/200:
#   Costs: hourly=4.47, km=0.4225, parking_mult=2.52
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1023.1km, time=30.6h, parking=527.8
#   ✓ Added to pool (total: 84)
#
# Cost Set 85/200:
#   Costs: hourly=3.43, km=0.4199, parking_mult=3.30
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1007.1km, time=30.6h, parking=690.9
#   ✓ Added to pool (total: 85)
#
# Cost Set 86/200:
#   Costs: hourly=2.22, km=0.1048, parking_mult=1.50
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1022.0km, time=30.9h, parking=314.1
#   ✓ Added to pool (total: 86)
#
# Cost Set 87/200:
#   Costs: hourly=1.96, km=0.1218, parking_mult=2.22
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1015.0km, time=30.5h, parking=464.8
#   ✓ Added to pool (total: 87)
#
# Cost Set 88/200:
#   Costs: hourly=4.41, km=0.4796, parking_mult=1.44
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1011.8km, time=30.5h, parking=301.7
#   ✓ Added to pool (total: 88)
#
# Cost Set 89/200:
#   Costs: hourly=2.21, km=0.3000, parking_mult=1.69
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1017.4km, time=30.7h, parking=353.9
#   ✓ Added to pool (total: 89)
#
# Cost Set 90/200:
#   Costs: hourly=5.00, km=0.3455, parking_mult=1.48
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1033.9km, time=30.9h, parking=310.1
#   ✓ Added to pool (total: 90)
#   💾 Saved 90 cost sets to cost_pool.json
#
#   ========================================================
#   CHECKPOINT: 90/200 cost sets in pool
#   Elapsed: 3.0 hours
#   Remaining: 3.7 hours
#   ========================================================
#
#
# Cost Set 91/200:
#   Costs: hourly=4.28, km=0.1674, parking_mult=3.31
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1013.2km, time=30.7h, parking=693.1
#   ✓ Added to pool (total: 91)
#
# Cost Set 92/200:
#   Costs: hourly=3.45, km=0.3968, parking_mult=3.84
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1018.5km, time=30.5h, parking=804.0
#   ✓ Added to pool (total: 92)
#
# Cost Set 93/200:
#   Costs: hourly=0.84, km=0.1337, parking_mult=2.65
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1047.8km, time=31.0h, parking=554.7
#   ✓ Added to pool (total: 93)
#
# Cost Set 94/200:
#   Costs: hourly=2.45, km=0.4415, parking_mult=2.34
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1117.0km, time=31.9h, parking=489.9
#   ✓ Added to pool (total: 94)
#
# Cost Set 95/200:
#   Costs: hourly=3.86, km=0.1158, parking_mult=1.09
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1013.5km, time=30.7h, parking=228.4
#   ✓ Added to pool (total: 95)
#
# Cost Set 96/200:
#   Costs: hourly=4.74, km=0.3165, parking_mult=3.66
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1017.5km, time=30.6h, parking=766.4
#   ✓ Added to pool (total: 96)
#
# Cost Set 97/200:
#   Costs: hourly=1.66, km=0.4432, parking_mult=2.48
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1035.4km, time=30.9h, parking=519.2
#   ✓ Added to pool (total: 97)
#
# Cost Set 98/200:
#   Costs: hourly=4.80, km=0.4402, parking_mult=2.58
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1011.7km, time=30.7h, parking=540.3
#   ✓ Added to pool (total: 98)
#
# Cost Set 99/200:
#   Costs: hourly=2.63, km=0.1593, parking_mult=2.46
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1141.0km, time=32.1h, parking=515.1
#   ✓ Added to pool (total: 99)
#
# Cost Set 100/200:
#   Costs: hourly=2.48, km=0.4300, parking_mult=1.66
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1036.9km, time=31.0h, parking=347.6
#   ✓ Added to pool (total: 100)
#   💾 Saved 100 cost sets to cost_pool.json
#
#   ========================================================
#   CHECKPOINT: 100/200 cost sets in pool
#   Elapsed: 3.3 hours
#   Remaining: 3.3 hours
#   ========================================================
#
#
# Cost Set 101/200:
#   Costs: hourly=4.75, km=0.0643, parking_mult=4.73
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1017.0km, time=30.6h, parking=990.3
#   ✓ Added to pool (total: 101)
#
# Cost Set 102/200:
#   Costs: hourly=1.17, km=0.2160, parking_mult=2.93
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1022.3km, time=30.7h, parking=613.3
#   ✓ Added to pool (total: 102)
#
# Cost Set 103/200:
#   Costs: hourly=1.32, km=0.0642, parking_mult=0.41
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1020.6km, time=30.8h, parking=85.9
#   ✓ Added to pool (total: 103)
#
# Cost Set 104/200:
#   Costs: hourly=1.88, km=0.3763, parking_mult=4.98
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1030.9km, time=30.9h, parking=1042.5
#   ✓ Added to pool (total: 104)
#
# Cost Set 105/200:
#   Costs: hourly=3.45, km=0.2160, parking_mult=0.60
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1028.2km, time=30.7h, parking=125.8
#   ✓ Added to pool (total: 105)
#
# Cost Set 106/200:
#   Costs: hourly=4.11, km=0.2394, parking_mult=3.44
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1016.5km, time=30.6h, parking=720.3
#   ✓ Added to pool (total: 106)
#
# Cost Set 107/200:
#   Costs: hourly=4.70, km=0.4857, parking_mult=2.67
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1007.2km, time=30.7h, parking=559.2
#   ✓ Added to pool (total: 107)
#
# Cost Set 108/200:
#   Costs: hourly=1.64, km=0.3984, parking_mult=3.52
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1022.0km, time=30.6h, parking=736.9
#   ✓ Added to pool (total: 108)
#
# Cost Set 109/200:
#   Costs: hourly=3.13, km=0.2317, parking_mult=2.17
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1011.8km, time=30.4h, parking=454.4
#   ✓ Added to pool (total: 109)
#
# Cost Set 110/200:
#   Costs: hourly=3.72, km=0.3723, parking_mult=4.44
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1015.5km, time=30.5h, parking=929.6
#   ✓ Added to pool (total: 110)
#   💾 Saved 110 cost sets to cost_pool.json
#
#   ========================================================
#   CHECKPOINT: 110/200 cost sets in pool
#   Elapsed: 3.7 hours
#   Remaining: 3.0 hours
#   ========================================================
#
#
# Cost Set 111/200:
#   Costs: hourly=4.39, km=0.1019, parking_mult=2.63
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1014.7km, time=30.6h, parking=550.8
#   ✓ Added to pool (total: 111)
#
# Cost Set 112/200:
#   Costs: hourly=1.07, km=0.4257, parking_mult=3.03
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1002.8km, time=30.4h, parking=634.3
#   ✓ Added to pool (total: 112)
#
# Cost Set 113/200:
#   Costs: hourly=1.05, km=0.4870, parking_mult=4.40
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1022.3km, time=30.8h, parking=921.0
#   ✓ Added to pool (total: 113)
#
# Cost Set 114/200:
#   Costs: hourly=1.11, km=0.0350, parking_mult=4.61
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1041.3km, time=30.9h, parking=965.0
#   ✓ Added to pool (total: 114)
#
# Cost Set 115/200:
#   Costs: hourly=1.48, km=0.4208, parking_mult=4.34
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1017.5km, time=30.6h, parking=908.5
#   ✓ Added to pool (total: 115)
#
# Cost Set 116/200:
#   Costs: hourly=4.44, km=0.2860, parking_mult=2.01
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1023.9km, time=30.8h, parking=421.0
#   ✓ Added to pool (total: 116)
#
# Cost Set 117/200:
#   Costs: hourly=1.93, km=0.1601, parking_mult=2.65
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1010.0km, time=30.4h, parking=554.8
#   ✓ Added to pool (total: 117)
#
# Cost Set 118/200:
#   Costs: hourly=3.09, km=0.1498, parking_mult=1.71
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1037.4km, time=30.9h, parking=358.1
#   ✓ Added to pool (total: 118)
#
# Cost Set 119/200:
#   Costs: hourly=3.14, km=0.0697, parking_mult=3.35
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1022.8km, time=30.7h, parking=701.4
#   ✓ Added to pool (total: 119)
#
# Cost Set 120/200:
#   Costs: hourly=1.37, km=0.2790, parking_mult=4.34
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1022.5km, time=30.7h, parking=908.5
#   ✓ Added to pool (total: 120)
#   💾 Saved 120 cost sets to cost_pool.json
#
#   ========================================================
#   CHECKPOINT: 120/200 cost sets in pool
#   Elapsed: 4.0 hours
#   Remaining: 2.7 hours
#   ========================================================
#
#
# Cost Set 121/200:
#   Costs: hourly=2.09, km=0.4421, parking_mult=4.73
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1015.6km, time=30.6h, parking=990.1
#   ✓ Added to pool (total: 121)
#
# Cost Set 122/200:
#   Costs: hourly=2.70, km=0.3740, parking_mult=4.66
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1017.6km, time=30.6h, parking=975.5
#   ✓ Added to pool (total: 122)
#
# Cost Set 123/200:
#   Costs: hourly=4.05, km=0.4058, parking_mult=3.10
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1020.5km, time=30.6h, parking=649.1
#   ✓ Added to pool (total: 123)
#
# Cost Set 124/200:
#   Costs: hourly=2.64, km=0.4706, parking_mult=3.95
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1041.3km, time=31.1h, parking=826.9
#   ✓ Added to pool (total: 124)
#
# Cost Set 125/200:
#   Costs: hourly=0.91, km=0.4149, parking_mult=2.55
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1002.7km, time=30.4h, parking=533.8
#   ✓ Added to pool (total: 125)
#
# Cost Set 126/200:
#   Costs: hourly=1.15, km=0.4169, parking_mult=1.69
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1014.7km, time=30.6h, parking=353.8
#   ✓ Added to pool (total: 126)
#
# Cost Set 127/200:
#   Costs: hourly=2.25, km=0.0154, parking_mult=1.83
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1030.7km, time=30.9h, parking=383.2
#   ✓ Added to pool (total: 127)
#
# Cost Set 128/200:
#   Costs: hourly=1.83, km=0.2691, parking_mult=4.64
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1014.3km, time=30.6h, parking=971.3
#   ✓ Added to pool (total: 128)
#
# Cost Set 129/200:
#   Costs: hourly=0.65, km=0.2730, parking_mult=1.74
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1043.8km, time=31.1h, parking=364.2
#   ✓ Added to pool (total: 129)
#
# Cost Set 130/200:
#   Costs: hourly=3.99, km=0.2131, parking_mult=1.20
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1020.7km, time=30.7h, parking=251.4
#   ✓ Added to pool (total: 130)
#   💾 Saved 130 cost sets to cost_pool.json
#
#   ========================================================
#   CHECKPOINT: 130/200 cost sets in pool
#   Elapsed: 4.4 hours
#   Remaining: 2.3 hours
#   ========================================================
#
#
# Cost Set 131/200:
#   Costs: hourly=4.86, km=0.2373, parking_mult=4.75
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1029.1km, time=30.7h, parking=994.5
#   ✓ Added to pool (total: 131)
#
# Cost Set 132/200:
#   Costs: hourly=3.14, km=0.2334, parking_mult=4.71
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=997.8km, time=30.3h, parking=986.0
#   ✓ Added to pool (total: 132)
#
# Cost Set 133/200:
#   Costs: hourly=2.84, km=0.4897, parking_mult=3.18
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1035.2km, time=31.0h, parking=665.8
#   ✓ Added to pool (total: 133)
#
# Cost Set 134/200:
#   Costs: hourly=0.88, km=0.1136, parking_mult=0.67
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1004.7km, time=30.3h, parking=140.3
#   ✓ Added to pool (total: 134)
#
# Cost Set 135/200:
#   Costs: hourly=4.45, km=0.0992, parking_mult=4.65
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1031.2km, time=30.9h, parking=973.6
#   ✓ Added to pool (total: 135)
#
# Cost Set 136/200:
#   Costs: hourly=2.28, km=0.2209, parking_mult=3.11
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1023.2km, time=30.8h, parking=651.1
#   ✓ Added to pool (total: 136)
#
# Cost Set 137/200:
#   Costs: hourly=1.06, km=0.2215, parking_mult=2.76
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1009.6km, time=30.4h, parking=577.8
#   ✓ Added to pool (total: 137)
#
# Cost Set 138/200:
#   Costs: hourly=2.18, km=0.4396, parking_mult=4.25
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1030.0km, time=31.0h, parking=902.0
#   ✓ Added to pool (total: 138)
#
# Cost Set 139/200:
#   Costs: hourly=0.93, km=0.2007, parking_mult=0.91
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1020.0km, time=30.7h, parking=190.5
#   ✓ Added to pool (total: 139)
#
# Cost Set 140/200:
#   Costs: hourly=3.74, km=0.4543, parking_mult=2.08
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1016.6km, time=30.6h, parking=435.6
#   ✓ Added to pool (total: 140)
#   💾 Saved 140 cost sets to cost_pool.json
#
#   ========================================================
#   CHECKPOINT: 140/200 cost sets in pool
#   Elapsed: 4.7 hours
#   Remaining: 2.0 hours
#   ========================================================
#
#
# Cost Set 141/200:
#   Costs: hourly=2.12, km=0.4591, parking_mult=3.32
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1026.7km, time=30.8h, parking=695.0
#   ✓ Added to pool (total: 141)
#
# Cost Set 142/200:
#   Costs: hourly=4.64, km=0.4617, parking_mult=2.00
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1012.5km, time=30.4h, parking=418.9
#   ✓ Added to pool (total: 142)
#
# Cost Set 143/200:
#   Costs: hourly=1.62, km=0.2145, parking_mult=3.50
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1036.0km, time=30.9h, parking=732.7
#   ✓ Added to pool (total: 143)
#
# Cost Set 144/200:
#   Costs: hourly=1.60, km=0.1180, parking_mult=2.74
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1015.5km, time=30.6h, parking=573.6
#   ✓ Added to pool (total: 144)
#
# Cost Set 145/200:
#   Costs: hourly=4.84, km=0.2682, parking_mult=1.86
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1020.7km, time=30.6h, parking=389.6
#   ✓ Added to pool (total: 145)
#
# Cost Set 146/200:
#   Costs: hourly=2.26, km=0.1739, parking_mult=3.15
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1022.8km, time=30.7h, parking=659.5
#   ✓ Added to pool (total: 146)
#
# Cost Set 147/200:
#   Costs: hourly=1.51, km=0.0215, parking_mult=3.99
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1026.6km, time=30.9h, parking=835.2
#   ✓ Added to pool (total: 147)
#
# Cost Set 148/200:
#   Costs: hourly=3.83, km=0.0633, parking_mult=1.80
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1023.1km, time=30.7h, parking=377.0
#   ✓ Added to pool (total: 148)
#
# Cost Set 149/200:
#   Costs: hourly=4.73, km=0.4472, parking_mult=3.16
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1010.0km, time=30.6h, parking=661.7
#   ✓ Added to pool (total: 149)
#
# Cost Set 150/200:
#   Costs: hourly=2.09, km=0.2332, parking_mult=4.12
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1019.5km, time=30.7h, parking=862.5
#   ✓ Added to pool (total: 150)
#   💾 Saved 150 cost sets to cost_pool.json
#
#   ========================================================
#   CHECKPOINT: 150/200 cost sets in pool
#   Elapsed: 5.0 hours
#   Remaining: 1.7 hours
#   ========================================================
#
#
# Cost Set 151/200:
#   Costs: hourly=4.06, km=0.4030, parking_mult=4.51
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1011.3km, time=30.5h, parking=944.2
#   ✓ Added to pool (total: 151)
#
# Cost Set 152/200:
#   Costs: hourly=2.76, km=0.4121, parking_mult=4.66
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1009.9km, time=30.5h, parking=975.5
#   ✓ Added to pool (total: 152)
#
# Cost Set 153/200:
#   Costs: hourly=0.54, km=0.2204, parking_mult=2.55
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1036.7km, time=31.1h, parking=533.8
#   ✓ Added to pool (total: 153)
#
# Cost Set 154/200:
#   Costs: hourly=2.34, km=0.1513, parking_mult=3.33
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1016.6km, time=30.4h, parking=697.1
#   ✓ Added to pool (total: 154)
#
# Cost Set 155/200:
#   Costs: hourly=3.22, km=0.2262, parking_mult=1.92
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1026.2km, time=30.6h, parking=402.1
#   ✓ Added to pool (total: 155)
#
# Cost Set 156/200:
#   Costs: hourly=3.67, km=0.4742, parking_mult=2.28
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1013.8km, time=30.6h, parking=477.5
#   ✓ Added to pool (total: 156)
#
# Cost Set 157/200:
#   Costs: hourly=2.88, km=0.3295, parking_mult=2.35
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1026.2km, time=30.9h, parking=492.1
#   ✓ Added to pool (total: 157)
#
# Cost Set 158/200:
#   Costs: hourly=2.22, km=0.1210, parking_mult=3.88
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1041.1km, time=31.1h, parking=812.2
#   ✓ Added to pool (total: 158)
#
# Cost Set 159/200:
#   Costs: hourly=1.53, km=0.3314, parking_mult=0.38
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1024.0km, time=30.8h, parking=79.6
#   ✓ Added to pool (total: 159)
#
# Cost Set 160/200:
#   Costs: hourly=1.98, km=0.4348, parking_mult=2.85
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1016.0km, time=30.6h, parking=596.6
#   ✓ Added to pool (total: 160)
#   💾 Saved 160 cost sets to cost_pool.json
#
#   ========================================================
#   CHECKPOINT: 160/200 cost sets in pool
#   Elapsed: 5.4 hours
#   Remaining: 1.3 hours
#   ========================================================
#
#
# Cost Set 161/200:
#   Costs: hourly=4.22, km=0.3794, parking_mult=2.75
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1015.4km, time=30.7h, parking=575.9
#   ✓ Added to pool (total: 161)
#
# Cost Set 162/200:
#   Costs: hourly=1.50, km=0.1927, parking_mult=3.41
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1017.1km, time=30.8h, parking=713.8
#   ✓ Added to pool (total: 162)
#
# Cost Set 163/200:
#   Costs: hourly=1.10, km=0.3591, parking_mult=1.87
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1028.1km, time=30.9h, parking=391.5
#   ✓ Added to pool (total: 163)
#
# Cost Set 164/200:
#   Costs: hourly=3.47, km=0.0538, parking_mult=3.83
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1040.9km, time=31.0h, parking=801.9
#   ✓ Added to pool (total: 164)
#
# Cost Set 165/200:
#   Costs: hourly=4.06, km=0.1516, parking_mult=0.47
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1013.0km, time=30.5h, parking=98.7
#   ✓ Added to pool (total: 165)
#
# Cost Set 166/200:
#   Costs: hourly=4.92, km=0.0761, parking_mult=4.59
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1161.4km, time=32.4h, parking=961.0
#   ✓ Added to pool (total: 166)
#
# Cost Set 167/200:
#   Costs: hourly=2.08, km=0.1578, parking_mult=1.98
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1052.0km, time=31.3h, parking=414.6
#   ✓ Added to pool (total: 167)
#
# Cost Set 168/200:
#   Costs: hourly=3.99, km=0.4489, parking_mult=1.70
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1023.4km, time=30.7h, parking=356.1
#   ✓ Added to pool (total: 168)
#
# Cost Set 169/200:
#   Costs: hourly=3.50, km=0.3117, parking_mult=2.99
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1016.2km, time=30.5h, parking=626.1
#   ✓ Added to pool (total: 169)
#
# Cost Set 170/200:
#   Costs: hourly=3.27, km=0.2546, parking_mult=0.70
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1015.8km, time=30.6h, parking=146.7
#   ✓ Added to pool (total: 170)
#   💾 Saved 170 cost sets to cost_pool.json
#
#   ========================================================
#   CHECKPOINT: 170/200 cost sets in pool
#   Elapsed: 5.7 hours
#   Remaining: 1.0 hours
#   ========================================================
#
#
# Cost Set 171/200:
#   Costs: hourly=0.75, km=0.3705, parking_mult=0.58
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1024.1km, time=31.0h, parking=121.5
#   ✓ Added to pool (total: 171)
#
# Cost Set 172/200:
#   Costs: hourly=3.00, km=0.3812, parking_mult=0.50
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1009.3km, time=30.6h, parking=104.9
#   ✓ Added to pool (total: 172)
#
# Cost Set 173/200:
#   Costs: hourly=2.18, km=0.3766, parking_mult=0.21
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1013.2km, time=30.4h, parking=44.1
#   ✓ Added to pool (total: 173)
#
# Cost Set 174/200:
#   Costs: hourly=1.15, km=0.3922, parking_mult=2.00
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1021.7km, time=30.7h, parking=418.7
#   ✓ Added to pool (total: 174)
#
# Cost Set 175/200:
#   Costs: hourly=2.07, km=0.2742, parking_mult=3.27
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1013.2km, time=30.8h, parking=684.6
#   ✓ Added to pool (total: 175)
#
# Cost Set 176/200:
#   Costs: hourly=3.98, km=0.0194, parking_mult=2.33
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1112.4km, time=31.7h, parking=487.9
#   ✓ Added to pool (total: 176)
#
# Cost Set 177/200:
#   Costs: hourly=3.09, km=0.0705, parking_mult=1.35
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1129.8km, time=32.0h, parking=282.8
#   ✓ Added to pool (total: 177)
#
# Cost Set 178/200:
#   Costs: hourly=4.39, km=0.3519, parking_mult=4.10
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1026.7km, time=30.7h, parking=858.5
#   ✓ Added to pool (total: 178)
#
# Cost Set 179/200:
#   Costs: hourly=3.12, km=0.1839, parking_mult=2.78
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1015.4km, time=30.8h, parking=582.1
#   ✓ Added to pool (total: 179)
#
# Cost Set 180/200:
#   Costs: hourly=4.59, km=0.3954, parking_mult=0.92
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1014.8km, time=30.6h, parking=192.9
#   ✓ Added to pool (total: 180)
#   💾 Saved 180 cost sets to cost_pool.json
#
#   ========================================================
#   CHECKPOINT: 180/200 cost sets in pool
#   Elapsed: 6.0 hours
#   Remaining: 0.7 hours
#   ========================================================
#
#
# Cost Set 181/200:
#   Costs: hourly=2.45, km=0.3057, parking_mult=1.35
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1006.8km, time=30.4h, parking=282.7
#   ✓ Added to pool (total: 181)
#
# Cost Set 182/200:
#   Costs: hourly=4.10, km=0.2360, parking_mult=4.20
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1024.3km, time=30.8h, parking=879.4
#   ✓ Added to pool (total: 182)
#
# Cost Set 183/200:
#   Costs: hourly=2.30, km=0.0998, parking_mult=3.77
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1037.7km, time=31.0h, parking=789.2
#   ✓ Added to pool (total: 183)
#
# Cost Set 184/200:
#   Costs: hourly=0.63, km=0.2407, parking_mult=4.94
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1047.5km, time=31.2h, parking=1034.0
#   ✓ Added to pool (total: 184)
#
# Cost Set 185/200:
#   Costs: hourly=3.60, km=0.3911, parking_mult=4.21
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1099.6km, time=31.6h, parking=881.4
#   ✓ Added to pool (total: 185)
#
# Cost Set 186/200:
#   Costs: hourly=2.63, km=0.0577, parking_mult=0.72
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1137.9km, time=32.0h, parking=150.9
#   ✓ Added to pool (total: 186)
#
# Cost Set 187/200:
#   Costs: hourly=1.29, km=0.2164, parking_mult=1.60
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1022.1km, time=30.8h, parking=335.0
#   ✓ Added to pool (total: 187)
#
# Cost Set 188/200:
#   Costs: hourly=0.80, km=0.4326, parking_mult=4.56
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1043.4km, time=31.3h, parking=954.5
#   ✓ Added to pool (total: 188)
#
# Cost Set 189/200:
#   Costs: hourly=3.39, km=0.4240, parking_mult=4.82
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1059.8km, time=31.2h, parking=1009.1
#   ✓ Added to pool (total: 189)
#
# Cost Set 190/200:
#   Costs: hourly=3.73, km=0.1513, parking_mult=1.86
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1018.5km, time=30.6h, parking=389.6
#   ✓ Added to pool (total: 190)
#   💾 Saved 190 cost sets to cost_pool.json
#
#   ========================================================
#   CHECKPOINT: 190/200 cost sets in pool
#   Elapsed: 6.4 hours
#   Remaining: 0.3 hours
#   ========================================================
#
#
# Cost Set 191/200:
#   Costs: hourly=2.79, km=0.0827, parking_mult=2.88
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1019.8km, time=30.7h, parking=603.0
#   ✓ Added to pool (total: 191)
#
# Cost Set 192/200:
#   Costs: hourly=3.23, km=0.3219, parking_mult=4.54
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1019.0km, time=30.6h, parking=950.5
#   ✓ Added to pool (total: 192)
#
# Cost Set 193/200:
#   Costs: hourly=2.84, km=0.2743, parking_mult=1.01
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1025.0km, time=30.9h, parking=211.6
#   ✓ Added to pool (total: 193)
#
# Cost Set 194/200:
#   Costs: hourly=1.94, km=0.2587, parking_mult=4.84
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1026.1km, time=30.8h, parking=1013.2
#   ✓ Added to pool (total: 194)
#
# Cost Set 195/200:
#   Costs: hourly=4.54, km=0.0306, parking_mult=3.46
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1010.4km, time=30.6h, parking=724.5
#   ✓ Added to pool (total: 195)
#
# Cost Set 196/200:
#   Costs: hourly=1.78, km=0.4081, parking_mult=3.39
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1020.7km, time=30.6h, parking=709.7
#   ✓ Added to pool (total: 196)
#
# Cost Set 197/200:
#   Costs: hourly=4.64, km=0.2982, parking_mult=1.99
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1016.5km, time=30.5h, parking=416.8
#   ✓ Added to pool (total: 197)
#
# Cost Set 198/200:
#   Costs: hourly=2.61, km=0.0413, parking_mult=3.08
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1013.1km, time=30.5h, parking=644.8
#   ✓ Added to pool (total: 198)
#
# Cost Set 199/200:
#   Costs: hourly=1.30, km=0.4263, parking_mult=2.41
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1015.3km, time=30.7h, parking=504.5
#   ✓ Added to pool (total: 199)
#
# Cost Set 200/200:
#   Costs: hourly=3.43, km=0.1429, parking_mult=4.59
#   ✓ Model uploaded, waiting 120s for optimization...
#   Features: dist=1014.9km, time=30.5h, parking=960.9
#   ✓ Added to pool (total: 200)
#   💾 Saved 200 cost sets to cost_pool.json
#
#   ========================================================
#   CHECKPOINT: 200/200 cost sets in pool
#   Elapsed: 6.7 hours
#   Remaining: 0.0 hours
#   ========================================================
#
#   💾 Saved 200 cost sets to cost_pool.json
#
# ============================================================
# PHASE 1 COMPLETE
# ============================================================
# Cost pool size: 200
# Total time: 6.7 hours
# Average time per cost set: 120.5 seconds
# Data saved to: cost_pool.json
# ============================================================

# %% [markdown]
# ## Load Existing Cost Pool (Optional)
#
# If you already have a cost pool file, load it here instead of rebuilding.

# %%
# Load existing pool (if you already built it)
# collector.load_cost_pool(COST_POOL_FILE)

# %% [markdown]
# ## Analyze Cost Pool
#
# Quick analysis of the generated cost pool.

# %%
# Analyze cost pool
if len(collector.cost_pool) > 0:
    df_pool = pd.DataFrame([
        {
            'pool_id': entry['pool_id'],
            **{f'cost_{k}': v for k, v in entry['costs'].items()},
            **{f'feat_{k}': v for k, v in entry['features'].items()}
        }
        for entry in collector.cost_pool
    ])
    
    print(f"Cost Pool Analysis:")
    print(f"  Pool size: {len(collector.cost_pool)}")
    print(f"\nCost parameter ranges:")
    print(df_pool[['cost_costPerTravelHour', 'cost_costPerKm', 'cost_parking_multiplier']].describe())
    print(f"\nSolution feature ranges:")
    print(df_pool[['feat_total_distance_km', 'feat_total_travel_hours', 'feat_avg_parking_difficulty']].describe())
else:
    print("Cost pool is empty. Run Phase 1 first!")
# Out:
# Cost Pool Analysis:
#   Pool size: 200
#
# Cost parameter ranges:
#        cost_costPerTravelHour  cost_costPerKm  cost_parking_multiplier
# count              200.000000      200.000000               200.000000
# mean                 2.737650        0.264520                 2.695950
# std                  1.266939        0.137846                 1.394347
# min                  0.540000        0.015400                 0.210000
# 25%                  1.607500        0.150925                 1.595000
# 50%                  2.760000        0.268650                 2.680000
# 75%                  3.777500        0.384000                 3.892500
# max                  5.000000        0.489700                 4.980000
#
# Solution feature ranges:
#        feat_total_distance_km  feat_total_travel_hours  \
# count              200.000000               200.000000
# mean              1024.663150                30.720250
# std                 26.073621                 0.355932
# min                992.980000                30.230000
# 25%               1012.410000                30.517500
# 50%               1017.620000                30.635000
# 75%               1026.690000                30.825000
# max               1161.360000                32.530000
#
#        feat_avg_parking_difficulty
# count                   200.000000
# mean                    564.521550
# std                     291.915679
# min                      44.110000
# 25%                     333.982500
# 50%                     561.130000
# 75%                     814.987500
# max                    1042.460000

# %%
import json
import numpy as np
from typing import List, Dict

class ParetoAnalyzer:
    """Quick Pareto front finder for 3D objectives"""
    
    def __init__(self, cost_pool: List[Dict]):
        self.cost_pool = cost_pool
        self.objectives = ['avg_parking_difficulty', 'total_travel_hours', 'total_distance_km']
    
    def dominates(self, a: Dict, b: Dict) -> bool:
        """Check if solution a dominates b"""
        better_in_one = False
        for obj in self.objectives:
            if a['features'][obj] > b['features'][obj]:
                return False
            if a['features'][obj] < b['features'][obj]:
                better_in_one = True
        return better_in_one
    
    def find_pareto_front(self) -> List[Dict]:
        """Find non-dominated solutions"""
        pareto = []
        for candidate in self.cost_pool:
            if not any(self.dominates(other, candidate) 
                      for other in self.cost_pool 
                      if other['pool_id'] != candidate['pool_id']):
                pareto.append(candidate)
        return pareto
    
    def normalize_objectives(self, solutions: List[Dict]) -> np.ndarray:
        """Min-max normalize to [0, 1]"""
        n = len(solutions)
        values = np.array([[s['features'][obj] for obj in self.objectives] 
                          for s in solutions])
        
        normalized = np.zeros_like(values)
        for j in range(len(self.objectives)):
            min_val, max_val = values[:, j].min(), values[:, j].max()
            if max_val > min_val:
                normalized[:, j] = (values[:, j] - min_val) / (max_val - min_val)
        return normalized
    
    def select_best(self, pareto_front: List[Dict], preferences: Dict) -> Dict:
        """Select from Pareto front using weighted distance"""
        if len(pareto_front) == 1:
            return pareto_front[0]
        
        normalized = self.normalize_objectives(pareto_front)
        weights = np.array([preferences['parking_importance'],
                          preferences['time_importance'],
                          preferences['distance_importance']])
        
        distances = np.sqrt(np.sum((normalized * weights) ** 2, axis=1))
        best_idx = np.argmin(distances)
        
        result = pareto_front[best_idx].copy()
        result['pareto_distance'] = float(distances[best_idx])
        return result

# %%
# Load and analyze
with open('cost_pool.json', 'r') as f:
    cost_pool = json.load(f)

print(f"Loaded {len(cost_pool)} solutions")

# Find Pareto front
analyzer = ParetoAnalyzer(cost_pool)
pareto_front = analyzer.find_pareto_front()

print(f"\nPareto front: {len(pareto_front)} solutions")
print(f"Reduction: {100 * (1 - len(pareto_front)/len(cost_pool)):.1f}% dominated")

# Show Pareto solutions
print("\nPareto solutions:")
for sol in pareto_front:
    print(f"  ID {sol['pool_id']:3d}: "
          f"parking={sol['features']['avg_parking_difficulty']:6.1f}, "
          f"time={sol['features']['total_travel_hours']:5.2f}, "
          f"dist={sol['features']['total_distance_km']:7.1f}")

# Test selection
test_prefs = {'parking_importance': 0.7, 'time_importance': 0.2, 'distance_importance': 0.1}
best = analyzer.select_best(pareto_front, test_prefs)
print(f"\nFor preferences {test_prefs}")
print(f"Selected: pool_id={best['pool_id']}, distance={best['pareto_distance']:.4f}")

# %% [markdown]
# ## Phase 2: Generate Training Samples
#
# This matches preferences to the cost pool and generates training samples.
#
# **This is very fast** (~instant for 400 samples) since we're just matching, not optimizing!

# %%
# Generate training samples by matching to pool
collector.generate_training_samples(
    n_samples=N_PREFERENCE_SAMPLES,
    match_threshold=MATCH_QUALITY_THRESHOLD,
    wait_seconds=WAIT_SECONDS,  # Only used if custom costs needed
    output_file=OUTPUT_FILE
)
# Out:
# ============================================================
# PHASE 2: GENERATING TRAINING SAMPLES
# ============================================================
# Cost pool size: 200
# Target samples: 400
# Match threshold: 500
# Output: training_data_v3_pool.json
# ============================================================
#
#
# Sample 1/400:
#   Preferences: parking=0.43, time=0.15, distance=0.27
#   Best match: pool_id=173, score=20091.33
#   ⚠️  Score too high (>500), generating custom costs...
#     Generating 5 custom costs (poor match in pool)...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 2
#       1 # Generate training samples by matching to pool
# ----> 2 collector.generate_training_samples(
#       3     n_samples=N_PREFERENCE_SAMPLES,
#       4     match_threshold=MATCH_QUALITY_THRESHOLD,
#       5     wait_seconds=WAIT_SECONDS,  # Only used if custom costs needed
#       6     output_file=OUTPUT_FILE
#       7 )
#
# Cell In[54], line 390, in CostPoolDataCollector.generate_training_samples(self, n_samples, match_threshold, wait_seconds, output_file)
#     388 if match['score'] > match_threshold:
#     389     print(f"  ⚠️  Score too high (>{match_threshold}), generating custom costs...")
# --> 390     custom_match = self.generate_custom_costs_for_preference(preferences, wait_seconds)
#     392     if custom_match is not None and custom_match['score'] < match['score']:
#     393         match = custom_match
#
# Cell In[54], line 331, in CostPoolDataCollector.generate_custom_costs_for_preference(self, preferences, wait_seconds)
#     328 if not self.send_to_odl(model, model_id):
#     329     continue
# --> 331 time.sleep(wait_seconds)
#     332 plan = self.get_plan(model_id)
#     333 features = self.extract_features(plan)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Analyze Training Data

# %%
# Load and analyze training data
with open(OUTPUT_FILE, 'r') as f:
    data = json.load(f)

print(f"Training Dataset Summary:")
print(f"  Total samples: {len(data)}")

# Convert to DataFrame
df_records = []
for sample in data:
    record = {
        'sample_num': sample['sample_num'],
        **{f'pref_{k}': v for k, v in sample['preferences'].items()},
        **{f'cost_{k}': v for k, v in sample['costs'].items()},
        **{f'feat_{k}': v for k, v in sample['features'].items()},
        'score': sample['score'],
        'pool_id': sample['pool_id']
    }
    df_records.append(record)

df = pd.DataFrame(df_records)

print(f"\nDataFrame shape: {df.shape}")
print(f"\nFirst few rows:")
print(df.head())

print(f"\nPreferences statistics:")
print(df[['pref_parking_importance', 'pref_time_importance', 'pref_distance_importance']].describe())

print(f"\nCosts statistics:")
print(df[['cost_costPerTravelHour', 'cost_costPerKm', 'cost_parking_multiplier']].describe())

print(f"\nFeatures statistics:")
print(df[['feat_total_distance_km', 'feat_total_travel_hours', 'feat_avg_parking_difficulty']].describe())

print(f"\nScore statistics:")
print(df['score'].describe())

# Count custom vs pool matches
custom_count = (df['pool_id'] == 'custom').sum()
pool_count = (df['pool_id'] != 'custom').sum()
print(f"\nMatch sources:")
print(f"  From pool: {pool_count} ({pool_count/len(df)*100:.1f}%)")
print(f"  Custom generated: {custom_count} ({custom_count/len(df)*100:.1f}%)")

# %% [markdown]
# ## Visualize Cost Pool Coverage
#
# Check if the cost pool covers diverse solutions.

# %%
import matplotlib.pyplot as plt

if len(collector.cost_pool) > 0:
    fig, axes = plt.subplots(1, 3, figsize=(15, 4))
    
    # Extract data
    distances = [e['features']['total_distance_km'] for e in collector.cost_pool]
    times = [e['features']['total_travel_hours'] for e in collector.cost_pool]
    parking = [e['features']['avg_parking_difficulty'] for e in collector.cost_pool]
    
    # Plot distributions
    axes[0].hist(distances, bins=30, edgecolor='black')
    axes[0].set_xlabel('Total Distance (km)')
    axes[0].set_ylabel('Count')
    axes[0].set_title('Distance Distribution in Pool')
    
    axes[1].hist(times, bins=30, edgecolor='black')
    axes[1].set_xlabel('Total Time (hours)')
    axes[1].set_ylabel('Count')
    axes[1].set_title('Time Distribution in Pool')
    
    axes[2].hist(parking, bins=30, edgecolor='black')
    axes[2].set_xlabel('Avg Parking Difficulty')
    axes[2].set_ylabel('Count')
    axes[2].set_title('Parking Distribution in Pool')
    
    plt.tight_layout()
    plt.show()
    
    print("Good coverage means all three histograms show diverse values!")
else:
    print("No cost pool data to visualize")

# %% [markdown]
# ## Generate More Samples (Optional)
#
# Want even more training data? Just run Phase 2 again!
#
# The cost pool can be reused to generate as many samples as you want.

# %%
# Generate another batch of samples
# collector.training_data = []  # Reset if you want fresh samples
# collector.generate_training_samples(
#     n_samples=200,
#     match_threshold=MATCH_QUALITY_THRESHOLD,
#     wait_seconds=WAIT_SECONDS,
#     output_file='training_data_v3_pool_batch2.json'
# )

# %% [markdown]
# ## Next Steps
#
# Congratulations! You now have:
#
# 1. ✅ **Cost Pool**: 300 diverse cost/solution pairs
# 2. ✅ **Training Data**: 400+ preference → cost samples
# 3. ✅ **Efficiency**: ~7.5 hours total (vs 20+ hours for old approach)
# 4. ✅ **Reusability**: Can generate more samples anytime
#
# Next:
# - 🔜 Train regression model: preferences → costs
# - 🔜 Validate model performance
# - 🔜 Deploy for real-time use
